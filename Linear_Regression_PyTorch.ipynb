# %% [markdown]
# <a href="https://colab.research.google.com/github/pshemach/PyTorch-Basics/blob/main/Linear_Regression_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np

# %%
inputs = np.array([[70,40,60],[100,60,90],[90,50,130],[80,30,40],[60,70,100]], dtype='float32')
inputs
# Out:
# array([[ 70.,  40.,  60.],
#        [100.,  60.,  90.],
#        [ 90.,  50., 130.],
#        [ 80.,  30.,  40.],
#        [ 60.,  70., 100.]], dtype=float32)

# %%
targets = np.array([[58,77],[78,100],[122,130],[25,35],[113,120]], dtype='float32')
targets
# Out:
# array([[ 58.,  77.],
#        [ 78., 100.],
#        [122., 130.],
#        [ 25.,  35.],
#        [113., 120.]], dtype=float32)

# %%
inputs_tensor = torch.from_numpy(inputs)
targets_tensor = torch.from_numpy(targets)

print(inputs_tensor)
print(targets_tensor)
# Out:
# tensor([[ 70.,  40.,  60.],
#         [100.,  60.,  90.],
#         [ 90.,  50., 130.],
#         [ 80.,  30.,  40.],
#         [ 60.,  70., 100.]])
# tensor([[ 58.,  77.],
#         [ 78., 100.],
#         [122., 130.],
#         [ 25.,  35.],
#         [113., 120.]])

# %%
weights = torch.randn(2, 3, requires_grad=True)
biases = torch.randn(2, requires_grad=True)

# %%
print('Weights\n',weights)
print('Biases\n',biases)
# Out:
# Weights
#  tensor([[ 0.2229, -0.9241, -1.0751],
#         [-1.7946,  0.3522, -1.0662]], requires_grad=True)
# Biases
#  tensor([ 0.1149, -1.3923], requires_grad=True)

# %%
inputs_tensor @ weights.t() + biases
# Out:
# tensor([[ -85.7545, -176.9037],
#         [-129.8036, -255.6862],
#         [-165.7969, -283.9117],
#         [ -52.7821, -177.0470],
#         [-158.7113, -191.0414]], grad_fn=<AddBackward0>)

# %%
def linear_regression_model(x, weights, biases):
  return x @ weights.t() + biases

# %%
harvest_prediction = linear_regression_model(inputs_tensor, weights=weights, biases=biases)
print(harvest_prediction)
# Out:
# tensor([[ -85.7545, -176.9037],
#         [-129.8036, -255.6862],
#         [-165.7969, -283.9117],
#         [ -52.7821, -177.0470],
#         [-158.7113, -191.0414]], grad_fn=<AddBackward0>)

# %%
print(targets_tensor)
# Out:
# tensor([[ 58.,  77.],
#         [ 78., 100.],
#         [122., 130.],
#         [ 25.,  35.],
#         [113., 120.]])

# %%
difference = harvest_prediction - targets_tensor
print(difference)
# Out:
# tensor([[-143.7545, -253.9037],
#         [-207.8036, -355.6862],
#         [-287.7969, -413.9117],
#         [ -77.7822, -212.0470],
#         [-271.7113, -311.0414]], grad_fn=<SubBackward0>)

# %%
difference*difference
# Out:
# tensor([[ 20665.3613,  64467.0820],
#         [ 43182.3516, 126512.6875],
#         [ 82827.0391, 171322.9062],
#         [  6050.0630,  44963.9492],
#         [ 73827.0312,  96746.7188]], grad_fn=<MulBackward0>)

# %%
torch.sum(difference*difference) / 10
# Out:
# tensor(73056.5156, grad_fn=<DivBackward0>)

# %%
torch.sum(difference*difference) / difference.numel()
# Out:
# tensor(73056.5156, grad_fn=<DivBackward0>)

# %%
def meanSquaredError(predictionTensor, targetsTensor):
  difference = predictionTensor - targetsTensor
  return torch.sum(difference*difference) / difference.numel()

# %%
model_loss = meanSquaredError(predictionTensor=harvest_prediction, targetsTensor=targets_tensor)
model_loss
# Out:
# tensor(73056.5156, grad_fn=<DivBackward0>)

# %%
model_loss.backward()

# %%
print('Metrix of the weights\n', weights)
# Out:
# Metrix of the weights
#  tensor([[ 0.2229, -0.9241, -1.0751],
#         [-1.7946,  0.3522, -1.0662]], requires_grad=True)

# %%
print('Derivative of the loss with regard to the weight elements')
print(weights.grad)
# Out:
# Derivative of the loss with regard to the weight elements
# tensor([[-15854.0293, -10792.2998, -19004.7227],
#         [-25244.0352, -16065.4424, -28128.1055]])

# %%
print(biases)
print(biases.grad)
# Out:
# tensor([ 0.1149, -1.3923], requires_grad=True)
# tensor([-197.7697, -309.3180])

# %%
with torch.no_grad():
  weights -= weights.grad * 1e-5
  biases -= biases.grad * 1e-5

# %%
print(weights)
# Out:
# tensor([[ 0.3814, -0.8162, -0.8851],
#         [-1.5422,  0.5128, -0.7850]], requires_grad=True)

# %%
print('Previous Prediction\n', harvest_prediction)
print('Previous Loss', model_loss)

new_pred = linear_regression_model(inputs_tensor, weights=weights, biases=biases)
new_loss = meanSquaredError(predictionTensor=new_pred, targetsTensor=targets_tensor)

print('New Prediction\n', new_pred)
print('New Loss\n', new_loss)
# Out:
# Previous Prediction
#  tensor([[ -85.7545, -176.9037],
#         [-129.8036, -255.6862],
#         [-165.7969, -283.9117],
#         [ -52.7821, -177.0470],
#         [-158.7113, -191.0414]], grad_fn=<AddBackward0>)
# Previous Loss tensor(73056.5156, grad_fn=<DivBackward0>)
# New Prediction
#  tensor([[ -58.9350, -135.9267],
#         [ -90.3680, -195.4845],
#         [-121.4240, -216.5897],
#         [ -29.2574, -140.7779],
#         [-122.6376, -136.5179]], grad_fn=<AddBackward0>)
# New Loss
#  tensor(50921.8398, grad_fn=<DivBackward0>)

# %%
weights.grad.zero_()
biases.grad.zero_()
# Out:
# tensor([0., 0.])

# %%
print(weights.grad)
print(biases.grad)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])
# tensor([0., 0.])

# %%
for i in range(2000):
  print("Epoch Number" + str(i))
  predictions = linear_regression_model(inputs_tensor, weights=weights, biases=biases)
  loss = meanSquaredError(predictionTensor=predictions, targetsTensor=targets_tensor)
  print('Loss'+ str(loss))
  loss.backward()
  with torch.no_grad():
    weights -= weights.grad * 1e-5
    biases -= biases.grad * 1e-5
    weights.grad.zero_()
    biases.grad.zero_()
# Out:
# Epoch Number0
# Losstensor(50921.8398, grad_fn=<DivBackward0>)
# Epoch Number1
# Losstensor(35577.9805, grad_fn=<DivBackward0>)
# Epoch Number2
# Losstensor(24940.8086, grad_fn=<DivBackward0>)
# Epoch Number3
# Losstensor(17565.8086, grad_fn=<DivBackward0>)
# Epoch Number4
# Losstensor(12451.8154, grad_fn=<DivBackward0>)
# Epoch Number5
# Losstensor(8904.9277, grad_fn=<DivBackward0>)
# Epoch Number6
# Losstensor(6444.2075, grad_fn=<DivBackward0>)
# Epoch Number7
# Losstensor(4736.3213, grad_fn=<DivBackward0>)
# Epoch Number8
# Losstensor(3550.2402, grad_fn=<DivBackward0>)
# Epoch Number9
# Losstensor(2725.8384, grad_fn=<DivBackward0>)
# Epoch Number10
# Losstensor(2152.1348, grad_fn=<DivBackward0>)
# Epoch Number11
# Losstensor(1752.2090, grad_fn=<DivBackward0>)
# Epoch Number12
# Losstensor(1472.7483, grad_fn=<DivBackward0>)
# Epoch Number13
# Losstensor(1276.8016, grad_fn=<DivBackward0>)
# Epoch Number14
# Losstensor(1138.7590, grad_fn=<DivBackward0>)
# Epoch Number15
# Losstensor(1040.8691, grad_fn=<DivBackward0>)
# Epoch Number16
# Losstensor(970.8296, grad_fn=<DivBackward0>)
# Epoch Number17
# Losstensor(920.1129, grad_fn=<DivBackward0>)
# Epoch Number18
# Losstensor(882.8090, grad_fn=<DivBackward0>)
# Epoch Number19
# Losstensor(854.8212, grad_fn=<DivBackward0>)
# Epoch Number20
# Losstensor(833.3098, grad_fn=<DivBackward0>)
# Epoch Number21
# Losstensor(816.3068, grad_fn=<DivBackward0>)
# Epoch Number22
# Losstensor(802.4479, grad_fn=<DivBackward0>)
# Epoch Number23
# Losstensor(790.7871, grad_fn=<DivBackward0>)
# Epoch Number24
# Losstensor(780.6688, grad_fn=<DivBackward0>)
# Epoch Number25
# Losstensor(771.6385, grad_fn=<DivBackward0>)
# Epoch Number26
# Losstensor(763.3809, grad_fn=<DivBackward0>)
# Epoch Number27
# Losstensor(755.6772, grad_fn=<DivBackward0>)
# Epoch Number28
# Losstensor(748.3756, grad_fn=<DivBackward0>)
# Epoch Number29
# Losstensor(741.3712, grad_fn=<DivBackward0>)
# Epoch Number30
# Losstensor(734.5901, grad_fn=<DivBackward0>)
# Epoch Number31
# Losstensor(727.9821, grad_fn=<DivBackward0>)
# Epoch Number32
# Losstensor(721.5114, grad_fn=<DivBackward0>)
# Epoch Number33
# Losstensor(715.1532, grad_fn=<DivBackward0>)
# Epoch Number34
# Losstensor(708.8905, grad_fn=<DivBackward0>)
# Epoch Number35
# Losstensor(702.7108, grad_fn=<DivBackward0>)
# Epoch Number36
# Losstensor(696.6060, grad_fn=<DivBackward0>)
# Epoch Number37
# Losstensor(690.5696, grad_fn=<DivBackward0>)
# Epoch Number38
# Losstensor(684.5973, grad_fn=<DivBackward0>)
# Epoch Number39
# Losstensor(678.6860, grad_fn=<DivBackward0>)
# Epoch Number40
# Losstensor(672.8332, grad_fn=<DivBackward0>)
# Epoch Number41
# Losstensor(667.0370, grad_fn=<DivBackward0>)
# Epoch Number42
# Losstensor(661.2964, grad_fn=<DivBackward0>)
# Epoch Number43
# Losstensor(655.6100, grad_fn=<DivBackward0>)
# Epoch Number44
# Losstensor(649.9769, grad_fn=<DivBackward0>)
# Epoch Number45
# Losstensor(644.3964, grad_fn=<DivBackward0>)
# Epoch Number46
# Losstensor(638.8677, grad_fn=<DivBackward0>)
# Epoch Number47
# Losstensor(633.3902, grad_fn=<DivBackward0>)
# Epoch Number48
# Losstensor(627.9635, grad_fn=<DivBackward0>)
# Epoch Number49
# Losstensor(622.5869, grad_fn=<DivBackward0>)
# Epoch Number50
# Losstensor(617.2597, grad_fn=<DivBackward0>)
# Epoch Number51
# Losstensor(611.9820, grad_fn=<DivBackward0>)
# Epoch Number52
# Losstensor(606.7526, grad_fn=<DivBackward0>)
# Epoch Number53
# Losstensor(601.5715, grad_fn=<DivBackward0>)
# Epoch Number54
# Losstensor(596.4382, grad_fn=<DivBackward0>)
# Epoch Number55
# Losstensor(591.3519, grad_fn=<DivBackward0>)
# Epoch Number56
# Losstensor(586.3127, grad_fn=<DivBackward0>)
# Epoch Number57
# Losstensor(581.3198, grad_fn=<DivBackward0>)
# Epoch Number58
# Losstensor(576.3728, grad_fn=<DivBackward0>)
# Epoch Number59
# Losstensor(571.4712, grad_fn=<DivBackward0>)
# Epoch Number60
# Losstensor(566.6149, grad_fn=<DivBackward0>)
# Epoch Number61
# Losstensor(561.8032, grad_fn=<DivBackward0>)
# Epoch Number62
# Losstensor(557.0356, grad_fn=<DivBackward0>)
# Epoch Number63
# Losstensor(552.3120, grad_fn=<DivBackward0>)
# Epoch Number64
# Losstensor(547.6318, grad_fn=<DivBackward0>)
# Epoch Number65
# Losstensor(542.9946, grad_fn=<DivBackward0>)
# Epoch Number66
# Losstensor(538.4000, grad_fn=<DivBackward0>)
# Epoch Number67
# Losstensor(533.8475, grad_fn=<DivBackward0>)
# Epoch Number68
# Losstensor(529.3370, grad_fn=<DivBackward0>)
# Epoch Number69
# Losstensor(524.8680, grad_fn=<DivBackward0>)
# Epoch Number70
# Losstensor(520.4401, grad_fn=<DivBackward0>)
# Epoch Number71
# Losstensor(516.0526, grad_fn=<DivBackward0>)
# Epoch Number72
# Losstensor(511.7056, grad_fn=<DivBackward0>)
# Epoch Number73
# Losstensor(507.3986, grad_fn=<DivBackward0>)
# Epoch Number74
# Losstensor(503.1309, grad_fn=<DivBackward0>)
# Epoch Number75
# Losstensor(498.9025, grad_fn=<DivBackward0>)
# Epoch Number76
# Losstensor(494.7130, grad_fn=<DivBackward0>)
# Epoch Number77
# Losstensor(490.5617, grad_fn=<DivBackward0>)
# Epoch Number78
# Losstensor(486.4488, grad_fn=<DivBackward0>)
# Epoch Number79
# Losstensor(482.3736, grad_fn=<DivBackward0>)
# Epoch Number80
# Losstensor(478.3356, grad_fn=<DivBackward0>)
# Epoch Number81
# Losstensor(474.3347, grad_fn=<DivBackward0>)
# Epoch Number82
# Losstensor(470.3708, grad_fn=<DivBackward0>)
# Epoch Number83
# Losstensor(466.4428, grad_fn=<DivBackward0>)
# Epoch Number84
# Losstensor(462.5511, grad_fn=<DivBackward0>)
# Epoch Number85
# Losstensor(458.6949, grad_fn=<DivBackward0>)
# Epoch Number86
# Losstensor(454.8744, grad_fn=<DivBackward0>)
# Epoch Number87
# Losstensor(451.0886, grad_fn=<DivBackward0>)
# Epoch Number88
# Losstensor(447.3375, grad_fn=<DivBackward0>)
# Epoch Number89
# Losstensor(443.6209, grad_fn=<DivBackward0>)
# Epoch Number90
# Losstensor(439.9384, grad_fn=<DivBackward0>)
# Epoch Number91
# Losstensor(436.2896, grad_fn=<DivBackward0>)
# Epoch Number92
# Losstensor(432.6742, grad_fn=<DivBackward0>)
# Epoch Number93
# Losstensor(429.0917, grad_fn=<DivBackward0>)
# Epoch Number94
# Losstensor(425.5423, grad_fn=<DivBackward0>)
# Epoch Number95
# Losstensor(422.0253, grad_fn=<DivBackward0>)
# Epoch Number96
# Losstensor(418.5405, grad_fn=<DivBackward0>)
# Epoch Number97
# Losstensor(415.0876, grad_fn=<DivBackward0>)
# Epoch Number98
# Losstensor(411.6663, grad_fn=<DivBackward0>)
# Epoch Number99
# Losstensor(408.2763, grad_fn=<DivBackward0>)
# Epoch Number100
# Losstensor(404.9173, grad_fn=<DivBackward0>)
# Epoch Number101
# Losstensor(401.5891, grad_fn=<DivBackward0>)
# Epoch Number102
# Losstensor(398.2913, grad_fn=<DivBackward0>)
# Epoch Number103
# Losstensor(395.0236, grad_fn=<DivBackward0>)
# Epoch Number104
# Losstensor(391.7859, grad_fn=<DivBackward0>)
# Epoch Number105
# Losstensor(388.5777, grad_fn=<DivBackward0>)
# Epoch Number106
# Losstensor(385.3988, grad_fn=<DivBackward0>)
# Epoch Number107
# Losstensor(382.2490, grad_fn=<DivBackward0>)
# Epoch Number108
# Losstensor(379.1280, grad_fn=<DivBackward0>)
# Epoch Number109
# Losstensor(376.0355, grad_fn=<DivBackward0>)
# Epoch Number110
# Losstensor(372.9711, grad_fn=<DivBackward0>)
# Epoch Number111
# Losstensor(369.9350, grad_fn=<DivBackward0>)
# Epoch Number112
# Losstensor(366.9264, grad_fn=<DivBackward0>)
# Epoch Number113
# Losstensor(363.9454, grad_fn=<DivBackward0>)
# Epoch Number114
# Losstensor(360.9915, grad_fn=<DivBackward0>)
# Epoch Number115
# Losstensor(358.0646, grad_fn=<DivBackward0>)
# Epoch Number116
# Losstensor(355.1644, grad_fn=<DivBackward0>)
# Epoch Number117
# Losstensor(352.2908, grad_fn=<DivBackward0>)
# Epoch Number118
# Losstensor(349.4433, grad_fn=<DivBackward0>)
# Epoch Number119
# Losstensor(346.6218, grad_fn=<DivBackward0>)
# Epoch Number120
# Losstensor(343.8259, grad_fn=<DivBackward0>)
# Epoch Number121
# Losstensor(341.0556, grad_fn=<DivBackward0>)
# Epoch Number122
# Losstensor(338.3106, grad_fn=<DivBackward0>)
# Epoch Number123
# Losstensor(335.5905, grad_fn=<DivBackward0>)
# Epoch Number124
# Losstensor(332.8953, grad_fn=<DivBackward0>)
# Epoch Number125
# Losstensor(330.2247, grad_fn=<DivBackward0>)
# Epoch Number126
# Losstensor(327.5782, grad_fn=<DivBackward0>)
# Epoch Number127
# Losstensor(324.9560, grad_fn=<DivBackward0>)
# Epoch Number128
# Losstensor(322.3577, grad_fn=<DivBackward0>)
# Epoch Number129
# Losstensor(319.7830, grad_fn=<DivBackward0>)
# Epoch Number130
# Losstensor(317.2318, grad_fn=<DivBackward0>)
# Epoch Number131
# Losstensor(314.7036, grad_fn=<DivBackward0>)
# Epoch Number132
# Losstensor(312.1986, grad_fn=<DivBackward0>)
# Epoch Number133
# Losstensor(309.7164, grad_fn=<DivBackward0>)
# Epoch Number134
# Losstensor(307.2568, grad_fn=<DivBackward0>)
# Epoch Number135
# Losstensor(304.8195, grad_fn=<DivBackward0>)
# Epoch Number136
# Losstensor(302.4043, grad_fn=<DivBackward0>)
# Epoch Number137
# Losstensor(300.0112, grad_fn=<DivBackward0>)
# Epoch Number138
# Losstensor(297.6398, grad_fn=<DivBackward0>)
# Epoch Number139
# Losstensor(295.2900, grad_fn=<DivBackward0>)
# Epoch Number140
# Losstensor(292.9615, grad_fn=<DivBackward0>)
# Epoch Number141
# Losstensor(290.6541, grad_fn=<DivBackward0>)
# Epoch Number142
# Losstensor(288.3677, grad_fn=<DivBackward0>)
# Epoch Number143
# Losstensor(286.1020, grad_fn=<DivBackward0>)
# Epoch Number144
# Losstensor(283.8570, grad_fn=<DivBackward0>)
# Epoch Number145
# Losstensor(281.6322, grad_fn=<DivBackward0>)
# Epoch Number146
# Losstensor(279.4278, grad_fn=<DivBackward0>)
# Epoch Number147
# Losstensor(277.2433, grad_fn=<DivBackward0>)
# Epoch Number148
# Losstensor(275.0786, grad_fn=<DivBackward0>)
# Epoch Number149
# Losstensor(272.9335, grad_fn=<DivBackward0>)
# Epoch Number150
# Losstensor(270.8079, grad_fn=<DivBackward0>)
# Epoch Number151
# Losstensor(268.7016, grad_fn=<DivBackward0>)
# Epoch Number152
# Losstensor(266.6144, grad_fn=<DivBackward0>)
# Epoch Number153
# Losstensor(264.5461, grad_fn=<DivBackward0>)
# Epoch Number154
# Losstensor(262.4965, grad_fn=<DivBackward0>)
# Epoch Number155
# Losstensor(260.4655, grad_fn=<DivBackward0>)
# Epoch Number156
# Losstensor(258.4528, grad_fn=<DivBackward0>)
# Epoch Number157
# Losstensor(256.4585, grad_fn=<DivBackward0>)
# Epoch Number158
# Losstensor(254.4821, grad_fn=<DivBackward0>)
# Epoch Number159
# Losstensor(252.5237, grad_fn=<DivBackward0>)
# Epoch Number160
# Losstensor(250.5829, grad_fn=<DivBackward0>)
# Epoch Number161
# Losstensor(248.6597, grad_fn=<DivBackward0>)
# Epoch Number162
# Losstensor(246.7539, grad_fn=<DivBackward0>)
# Epoch Number163
# Losstensor(244.8654, grad_fn=<DivBackward0>)
# Epoch Number164
# Losstensor(242.9939, grad_fn=<DivBackward0>)
# Epoch Number165
# Losstensor(241.1394, grad_fn=<DivBackward0>)
# Epoch Number166
# Losstensor(239.3015, grad_fn=<DivBackward0>)
# Epoch Number167
# Losstensor(237.4802, grad_fn=<DivBackward0>)
# Epoch Number168
# Losstensor(235.6755, grad_fn=<DivBackward0>)
# Epoch Number169
# Losstensor(233.8871, grad_fn=<DivBackward0>)
# Epoch Number170
# Losstensor(232.1148, grad_fn=<DivBackward0>)
# Epoch Number171
# Losstensor(230.3584, grad_fn=<DivBackward0>)
# Epoch Number172
# Losstensor(228.6180, grad_fn=<DivBackward0>)
# Epoch Number173
# Losstensor(226.8932, grad_fn=<DivBackward0>)
# Epoch Number174
# Losstensor(225.1840, grad_fn=<DivBackward0>)
# Epoch Number175
# Losstensor(223.4901, grad_fn=<DivBackward0>)
# Epoch Number176
# Losstensor(221.8117, grad_fn=<DivBackward0>)
# Epoch Number177
# Losstensor(220.1482, grad_fn=<DivBackward0>)
# Epoch Number178
# Losstensor(218.4998, grad_fn=<DivBackward0>)
# Epoch Number179
# Losstensor(216.8662, grad_fn=<DivBackward0>)
# Epoch Number180
# Losstensor(215.2473, grad_fn=<DivBackward0>)
# Epoch Number181
# Losstensor(213.6430, grad_fn=<DivBackward0>)
# Epoch Number182
# Losstensor(212.0531, grad_fn=<DivBackward0>)
# Epoch Number183
# Losstensor(210.4777, grad_fn=<DivBackward0>)
# Epoch Number184
# Losstensor(208.9163, grad_fn=<DivBackward0>)
# Epoch Number185
# Losstensor(207.3689, grad_fn=<DivBackward0>)
# Epoch Number186
# Losstensor(205.8354, grad_fn=<DivBackward0>)
# Epoch Number187
# Losstensor(204.3159, grad_fn=<DivBackward0>)
# Epoch Number188
# Losstensor(202.8099, grad_fn=<DivBackward0>)
# Epoch Number189
# Losstensor(201.3174, grad_fn=<DivBackward0>)
# Epoch Number190
# Losstensor(199.8384, grad_fn=<DivBackward0>)
# Epoch Number191
# Losstensor(198.3725, grad_fn=<DivBackward0>)
# Epoch Number192
# Losstensor(196.9200, grad_fn=<DivBackward0>)
# Epoch Number193
# Losstensor(195.4804, grad_fn=<DivBackward0>)
# Epoch Number194
# Losstensor(194.0537, grad_fn=<DivBackward0>)
# Epoch Number195
# Losstensor(192.6399, grad_fn=<DivBackward0>)
# Epoch Number196
# Losstensor(191.2387, grad_fn=<DivBackward0>)
# Epoch Number197
# Losstensor(189.8501, grad_fn=<DivBackward0>)
# Epoch Number198
# Losstensor(188.4740, grad_fn=<DivBackward0>)
# Epoch Number199
# Losstensor(187.1100, grad_fn=<DivBackward0>)
# Epoch Number200
# Losstensor(185.7583, grad_fn=<DivBackward0>)
# Epoch Number201
# Losstensor(184.4188, grad_fn=<DivBackward0>)
# Epoch Number202
# Losstensor(183.0913, grad_fn=<DivBackward0>)
# Epoch Number203
# Losstensor(181.7756, grad_fn=<DivBackward0>)
# Epoch Number204
# Losstensor(180.4717, grad_fn=<DivBackward0>)
# Epoch Number205
# Losstensor(179.1795, grad_fn=<DivBackward0>)
# Epoch Number206
# Losstensor(177.8988, grad_fn=<DivBackward0>)
# Epoch Number207
# Losstensor(176.6296, grad_fn=<DivBackward0>)
# Epoch Number208
# Losstensor(175.3717, grad_fn=<DivBackward0>)
# Epoch Number209
# Losstensor(174.1251, grad_fn=<DivBackward0>)
# Epoch Number210
# Losstensor(172.8895, grad_fn=<DivBackward0>)
# Epoch Number211
# Losstensor(171.6650, grad_fn=<DivBackward0>)
# Epoch Number212
# Losstensor(170.4514, grad_fn=<DivBackward0>)
# Epoch Number213
# Losstensor(169.2487, grad_fn=<DivBackward0>)
# Epoch Number214
# Losstensor(168.0566, grad_fn=<DivBackward0>)
# Epoch Number215
# Losstensor(166.8753, grad_fn=<DivBackward0>)
# Epoch Number216
# Losstensor(165.7044, grad_fn=<DivBackward0>)
# Epoch Number217
# Losstensor(164.5439, grad_fn=<DivBackward0>)
# Epoch Number218
# Losstensor(163.3938, grad_fn=<DivBackward0>)
# Epoch Number219
# Losstensor(162.2540, grad_fn=<DivBackward0>)
# Epoch Number220
# Losstensor(161.1243, grad_fn=<DivBackward0>)
# Epoch Number221
# Losstensor(160.0046, grad_fn=<DivBackward0>)
# Epoch Number222
# Losstensor(158.8949, grad_fn=<DivBackward0>)
# Epoch Number223
# Losstensor(157.7951, grad_fn=<DivBackward0>)
# Epoch Number224
# Losstensor(156.7050, grad_fn=<DivBackward0>)
# Epoch Number225
# Losstensor(155.6247, grad_fn=<DivBackward0>)
# Epoch Number226
# Losstensor(154.5539, grad_fn=<DivBackward0>)
# Epoch Number227
# Losstensor(153.4926, grad_fn=<DivBackward0>)
# Epoch Number228
# Losstensor(152.4408, grad_fn=<DivBackward0>)
# Epoch Number229
# Losstensor(151.3983, grad_fn=<DivBackward0>)
# Epoch Number230
# Losstensor(150.3650, grad_fn=<DivBackward0>)
# Epoch Number231
# Losstensor(149.3409, grad_fn=<DivBackward0>)
# Epoch Number232
# Losstensor(148.3259, grad_fn=<DivBackward0>)
# Epoch Number233
# Losstensor(147.3198, grad_fn=<DivBackward0>)
# Epoch Number234
# Losstensor(146.3227, grad_fn=<DivBackward0>)
# Epoch Number235
# Losstensor(145.3344, grad_fn=<DivBackward0>)
# Epoch Number236
# Losstensor(144.3549, grad_fn=<DivBackward0>)
# Epoch Number237
# Losstensor(143.3839, grad_fn=<DivBackward0>)
# Epoch Number238
# Losstensor(142.4218, grad_fn=<DivBackward0>)
# Epoch Number239
# Losstensor(141.4680, grad_fn=<DivBackward0>)
# Epoch Number240
# Losstensor(140.5226, grad_fn=<DivBackward0>)
# Epoch Number241
# Losstensor(139.5856, grad_fn=<DivBackward0>)
# Epoch Number242
# Losstensor(138.6569, grad_fn=<DivBackward0>)
# Epoch Number243
# Losstensor(137.7363, grad_fn=<DivBackward0>)
# Epoch Number244
# Losstensor(136.8240, grad_fn=<DivBackward0>)
# Epoch Number245
# Losstensor(135.9196, grad_fn=<DivBackward0>)
# Epoch Number246
# Losstensor(135.0232, grad_fn=<DivBackward0>)
# Epoch Number247
# Losstensor(134.1348, grad_fn=<DivBackward0>)
# Epoch Number248
# Losstensor(133.2541, grad_fn=<DivBackward0>)
# Epoch Number249
# Losstensor(132.3813, grad_fn=<DivBackward0>)
# Epoch Number250
# Losstensor(131.5161, grad_fn=<DivBackward0>)
# Epoch Number251
# Losstensor(130.6584, grad_fn=<DivBackward0>)
# Epoch Number252
# Losstensor(129.8084, grad_fn=<DivBackward0>)
# Epoch Number253
# Losstensor(128.9659, grad_fn=<DivBackward0>)
# Epoch Number254
# Losstensor(128.1307, grad_fn=<DivBackward0>)
# Epoch Number255
# Losstensor(127.3029, grad_fn=<DivBackward0>)
# Epoch Number256
# Losstensor(126.4823, grad_fn=<DivBackward0>)
# Epoch Number257
# Losstensor(125.6690, grad_fn=<DivBackward0>)
# Epoch Number258
# Losstensor(124.8628, grad_fn=<DivBackward0>)
# Epoch Number259
# Losstensor(124.0636, grad_fn=<DivBackward0>)
# Epoch Number260
# Losstensor(123.2715, grad_fn=<DivBackward0>)
# Epoch Number261
# Losstensor(122.4863, grad_fn=<DivBackward0>)
# Epoch Number262
# Losstensor(121.7080, grad_fn=<DivBackward0>)
# Epoch Number263
# Losstensor(120.9365, grad_fn=<DivBackward0>)
# Epoch Number264
# Losstensor(120.1718, grad_fn=<DivBackward0>)
# Epoch Number265
# Losstensor(119.4137, grad_fn=<DivBackward0>)
# Epoch Number266
# Losstensor(118.6623, grad_fn=<DivBackward0>)
# Epoch Number267
# Losstensor(117.9174, grad_fn=<DivBackward0>)
# Epoch Number268
# Losstensor(117.1791, grad_fn=<DivBackward0>)
# Epoch Number269
# Losstensor(116.4472, grad_fn=<DivBackward0>)
# Epoch Number270
# Losstensor(115.7218, grad_fn=<DivBackward0>)
# Epoch Number271
# Losstensor(115.0026, grad_fn=<DivBackward0>)
# Epoch Number272
# Losstensor(114.2896, grad_fn=<DivBackward0>)
# Epoch Number273
# Losstensor(113.5829, grad_fn=<DivBackward0>)
# Epoch Number274
# Losstensor(112.8824, grad_fn=<DivBackward0>)
# Epoch Number275
# Losstensor(112.1880, grad_fn=<DivBackward0>)
# Epoch Number276
# Losstensor(111.4997, grad_fn=<DivBackward0>)
# Epoch Number277
# Losstensor(110.8173, grad_fn=<DivBackward0>)
# Epoch Number278
# Losstensor(110.1409, grad_fn=<DivBackward0>)
# Epoch Number279
# Losstensor(109.4703, grad_fn=<DivBackward0>)
# Epoch Number280
# Losstensor(108.8055, grad_fn=<DivBackward0>)
# Epoch Number281
# Losstensor(108.1465, grad_fn=<DivBackward0>)
# Epoch Number282
# Losstensor(107.4933, grad_fn=<DivBackward0>)
# Epoch Number283
# Losstensor(106.8457, grad_fn=<DivBackward0>)
# Epoch Number284
# Losstensor(106.2037, grad_fn=<DivBackward0>)
# Epoch Number285
# Losstensor(105.5674, grad_fn=<DivBackward0>)
# Epoch Number286
# Losstensor(104.9364, grad_fn=<DivBackward0>)
# Epoch Number287
# Losstensor(104.3110, grad_fn=<DivBackward0>)
# Epoch Number288
# Losstensor(103.6910, grad_fn=<DivBackward0>)
# Epoch Number289
# Losstensor(103.0764, grad_fn=<DivBackward0>)
# Epoch Number290
# Losstensor(102.4671, grad_fn=<DivBackward0>)
# Epoch Number291
# Losstensor(101.8630, grad_fn=<DivBackward0>)
# Epoch Number292
# Losstensor(101.2642, grad_fn=<DivBackward0>)
# Epoch Number293
# Losstensor(100.6705, grad_fn=<DivBackward0>)
# Epoch Number294
# Losstensor(100.0819, grad_fn=<DivBackward0>)
# Epoch Number295
# Losstensor(99.4985, grad_fn=<DivBackward0>)
# Epoch Number296
# Losstensor(98.9200, grad_fn=<DivBackward0>)
# Epoch Number297
# Losstensor(98.3465, grad_fn=<DivBackward0>)
# Epoch Number298
# Losstensor(97.7781, grad_fn=<DivBackward0>)
# Epoch Number299
# Losstensor(97.2144, grad_fn=<DivBackward0>)
# Epoch Number300
# Losstensor(96.6556, grad_fn=<DivBackward0>)
# Epoch Number301
# Losstensor(96.1017, grad_fn=<DivBackward0>)
# Epoch Number302
# Losstensor(95.5524, grad_fn=<DivBackward0>)
# Epoch Number303
# Losstensor(95.0079, grad_fn=<DivBackward0>)
# Epoch Number304
# Losstensor(94.4682, grad_fn=<DivBackward0>)
# Epoch Number305
# Losstensor(93.9329, grad_fn=<DivBackward0>)
# Epoch Number306
# Losstensor(93.4023, grad_fn=<DivBackward0>)
# Epoch Number307
# Losstensor(92.8763, grad_fn=<DivBackward0>)
# Epoch Number308
# Losstensor(92.3548, grad_fn=<DivBackward0>)
# Epoch Number309
# Losstensor(91.8376, grad_fn=<DivBackward0>)
# Epoch Number310
# Losstensor(91.3249, grad_fn=<DivBackward0>)
# Epoch Number311
# Losstensor(90.8166, grad_fn=<DivBackward0>)
# Epoch Number312
# Losstensor(90.3127, grad_fn=<DivBackward0>)
# Epoch Number313
# Losstensor(89.8131, grad_fn=<DivBackward0>)
# Epoch Number314
# Losstensor(89.3177, grad_fn=<DivBackward0>)
# Epoch Number315
# Losstensor(88.8266, grad_fn=<DivBackward0>)
# Epoch Number316
# Losstensor(88.3396, grad_fn=<DivBackward0>)
# Epoch Number317
# Losstensor(87.8568, grad_fn=<DivBackward0>)
# Epoch Number318
# Losstensor(87.3781, grad_fn=<DivBackward0>)
# Epoch Number319
# Losstensor(86.9035, grad_fn=<DivBackward0>)
# Epoch Number320
# Losstensor(86.4329, grad_fn=<DivBackward0>)
# Epoch Number321
# Losstensor(85.9663, grad_fn=<DivBackward0>)
# Epoch Number322
# Losstensor(85.5037, grad_fn=<DivBackward0>)
# Epoch Number323
# Losstensor(85.0450, grad_fn=<DivBackward0>)
# Epoch Number324
# Losstensor(84.5901, grad_fn=<DivBackward0>)
# Epoch Number325
# Losstensor(84.1392, grad_fn=<DivBackward0>)
# Epoch Number326
# Losstensor(83.6921, grad_fn=<DivBackward0>)
# Epoch Number327
# Losstensor(83.2486, grad_fn=<DivBackward0>)
# Epoch Number328
# Losstensor(82.8091, grad_fn=<DivBackward0>)
# Epoch Number329
# Losstensor(82.3732, grad_fn=<DivBackward0>)
# Epoch Number330
# Losstensor(81.9410, grad_fn=<DivBackward0>)
# Epoch Number331
# Losstensor(81.5125, grad_fn=<DivBackward0>)
# Epoch Number332
# Losstensor(81.0875, grad_fn=<DivBackward0>)
# Epoch Number333
# Losstensor(80.6662, grad_fn=<DivBackward0>)
# Epoch Number334
# Losstensor(80.2484, grad_fn=<DivBackward0>)
# Epoch Number335
# Losstensor(79.8341, grad_fn=<DivBackward0>)
# Epoch Number336
# Losstensor(79.4234, grad_fn=<DivBackward0>)
# Epoch Number337
# Losstensor(79.0160, grad_fn=<DivBackward0>)
# Epoch Number338
# Losstensor(78.6122, grad_fn=<DivBackward0>)
# Epoch Number339
# Losstensor(78.2116, grad_fn=<DivBackward0>)
# Epoch Number340
# Losstensor(77.8145, grad_fn=<DivBackward0>)
# Epoch Number341
# Losstensor(77.4207, grad_fn=<DivBackward0>)
# Epoch Number342
# Losstensor(77.0301, grad_fn=<DivBackward0>)
# Epoch Number343
# Losstensor(76.6429, grad_fn=<DivBackward0>)
# Epoch Number344
# Losstensor(76.2589, grad_fn=<DivBackward0>)
# Epoch Number345
# Losstensor(75.8781, grad_fn=<DivBackward0>)
# Epoch Number346
# Losstensor(75.5005, grad_fn=<DivBackward0>)
# Epoch Number347
# Losstensor(75.1261, grad_fn=<DivBackward0>)
# Epoch Number348
# Losstensor(74.7547, grad_fn=<DivBackward0>)
# Epoch Number349
# Losstensor(74.3865, grad_fn=<DivBackward0>)
# Epoch Number350
# Losstensor(74.0213, grad_fn=<DivBackward0>)
# Epoch Number351
# Losstensor(73.6592, grad_fn=<DivBackward0>)
# Epoch Number352
# Losstensor(73.3001, grad_fn=<DivBackward0>)
# Epoch Number353
# Losstensor(72.9440, grad_fn=<DivBackward0>)
# Epoch Number354
# Losstensor(72.5909, grad_fn=<DivBackward0>)
# Epoch Number355
# Losstensor(72.2407, grad_fn=<DivBackward0>)
# Epoch Number356
# Losstensor(71.8933, grad_fn=<DivBackward0>)
# Epoch Number357
# Losstensor(71.5489, grad_fn=<DivBackward0>)
# Epoch Number358
# Losstensor(71.2074, grad_fn=<DivBackward0>)
# Epoch Number359
# Losstensor(70.8685, grad_fn=<DivBackward0>)
# Epoch Number360
# Losstensor(70.5326, grad_fn=<DivBackward0>)
# Epoch Number361
# Losstensor(70.1995, grad_fn=<DivBackward0>)
# Epoch Number362
# Losstensor(69.8691, grad_fn=<DivBackward0>)
# Epoch Number363
# Losstensor(69.5414, grad_fn=<DivBackward0>)
# Epoch Number364
# Losstensor(69.2164, grad_fn=<DivBackward0>)
# Epoch Number365
# Losstensor(68.8941, grad_fn=<DivBackward0>)
# Epoch Number366
# Losstensor(68.5744, grad_fn=<DivBackward0>)
# Epoch Number367
# Losstensor(68.2574, grad_fn=<DivBackward0>)
# Epoch Number368
# Losstensor(67.9430, grad_fn=<DivBackward0>)
# Epoch Number369
# Losstensor(67.6312, grad_fn=<DivBackward0>)
# Epoch Number370
# Losstensor(67.3219, grad_fn=<DivBackward0>)
# Epoch Number371
# Losstensor(67.0152, grad_fn=<DivBackward0>)
# Epoch Number372
# Losstensor(66.7110, grad_fn=<DivBackward0>)
# Epoch Number373
# Losstensor(66.4093, grad_fn=<DivBackward0>)
# Epoch Number374
# Losstensor(66.1100, grad_fn=<DivBackward0>)
# Epoch Number375
# Losstensor(65.8132, grad_fn=<DivBackward0>)
# Epoch Number376
# Losstensor(65.5189, grad_fn=<DivBackward0>)
# Epoch Number377
# Losstensor(65.2269, grad_fn=<DivBackward0>)
# Epoch Number378
# Losstensor(64.9373, grad_fn=<DivBackward0>)
# Epoch Number379
# Losstensor(64.6500, grad_fn=<DivBackward0>)
# Epoch Number380
# Losstensor(64.3651, grad_fn=<DivBackward0>)
# Epoch Number381
# Losstensor(64.0826, grad_fn=<DivBackward0>)
# Epoch Number382
# Losstensor(63.8023, grad_fn=<DivBackward0>)
# Epoch Number383
# Losstensor(63.5243, grad_fn=<DivBackward0>)
# Epoch Number384
# Losstensor(63.2485, grad_fn=<DivBackward0>)
# Epoch Number385
# Losstensor(62.9751, grad_fn=<DivBackward0>)
# Epoch Number386
# Losstensor(62.7037, grad_fn=<DivBackward0>)
# Epoch Number387
# Losstensor(62.4347, grad_fn=<DivBackward0>)
# Epoch Number388
# Losstensor(62.1677, grad_fn=<DivBackward0>)
# Epoch Number389
# Losstensor(61.9030, grad_fn=<DivBackward0>)
# Epoch Number390
# Losstensor(61.6403, grad_fn=<DivBackward0>)
# Epoch Number391
# Losstensor(61.3798, grad_fn=<DivBackward0>)
# Epoch Number392
# Losstensor(61.1214, grad_fn=<DivBackward0>)
# Epoch Number393
# Losstensor(60.8651, grad_fn=<DivBackward0>)
# Epoch Number394
# Losstensor(60.6108, grad_fn=<DivBackward0>)
# Epoch Number395
# Losstensor(60.3586, grad_fn=<DivBackward0>)
# Epoch Number396
# Losstensor(60.1084, grad_fn=<DivBackward0>)
# Epoch Number397
# Losstensor(59.8602, grad_fn=<DivBackward0>)
# Epoch Number398
# Losstensor(59.6140, grad_fn=<DivBackward0>)
# Epoch Number399
# Losstensor(59.3698, grad_fn=<DivBackward0>)
# Epoch Number400
# Losstensor(59.1275, grad_fn=<DivBackward0>)
# Epoch Number401
# Losstensor(58.8872, grad_fn=<DivBackward0>)
# Epoch Number402
# Losstensor(58.6487, grad_fn=<DivBackward0>)
# Epoch Number403
# Losstensor(58.4122, grad_fn=<DivBackward0>)
# Epoch Number404
# Losstensor(58.1776, grad_fn=<DivBackward0>)
# Epoch Number405
# Losstensor(57.9448, grad_fn=<DivBackward0>)
# Epoch Number406
# Losstensor(57.7139, grad_fn=<DivBackward0>)
# Epoch Number407
# Losstensor(57.4848, grad_fn=<DivBackward0>)
# Epoch Number408
# Losstensor(57.2575, grad_fn=<DivBackward0>)
# Epoch Number409
# Losstensor(57.0321, grad_fn=<DivBackward0>)
# Epoch Number410
# Losstensor(56.8084, grad_fn=<DivBackward0>)
# Epoch Number411
# Losstensor(56.5865, grad_fn=<DivBackward0>)
# Epoch Number412
# Losstensor(56.3664, grad_fn=<DivBackward0>)
# Epoch Number413
# Losstensor(56.1479, grad_fn=<DivBackward0>)
# Epoch Number414
# Losstensor(55.9313, grad_fn=<DivBackward0>)
# Epoch Number415
# Losstensor(55.7163, grad_fn=<DivBackward0>)
# Epoch Number416
# Losstensor(55.5031, grad_fn=<DivBackward0>)
# Epoch Number417
# Losstensor(55.2914, grad_fn=<DivBackward0>)
# Epoch Number418
# Losstensor(55.0815, grad_fn=<DivBackward0>)
# Epoch Number419
# Losstensor(54.8731, grad_fn=<DivBackward0>)
# Epoch Number420
# Losstensor(54.6665, grad_fn=<DivBackward0>)
# Epoch Number421
# Losstensor(54.4615, grad_fn=<DivBackward0>)
# Epoch Number422
# Losstensor(54.2580, grad_fn=<DivBackward0>)
# Epoch Number423
# Losstensor(54.0562, grad_fn=<DivBackward0>)
# Epoch Number424
# Losstensor(53.8559, grad_fn=<DivBackward0>)
# Epoch Number425
# Losstensor(53.6572, grad_fn=<DivBackward0>)
# Epoch Number426
# Losstensor(53.4601, grad_fn=<DivBackward0>)
# Epoch Number427
# Losstensor(53.2644, grad_fn=<DivBackward0>)
# Epoch Number428
# Losstensor(53.0703, grad_fn=<DivBackward0>)
# Epoch Number429
# Losstensor(52.8777, grad_fn=<DivBackward0>)
# Epoch Number430
# Losstensor(52.6866, grad_fn=<DivBackward0>)
# Epoch Number431
# Losstensor(52.4970, grad_fn=<DivBackward0>)
# Epoch Number432
# Losstensor(52.3089, grad_fn=<DivBackward0>)
# Epoch Number433
# Losstensor(52.1221, grad_fn=<DivBackward0>)
# Epoch Number434
# Losstensor(51.9369, grad_fn=<DivBackward0>)
# Epoch Number435
# Losstensor(51.7531, grad_fn=<DivBackward0>)
# Epoch Number436
# Losstensor(51.5707, grad_fn=<DivBackward0>)
# Epoch Number437
# Losstensor(51.3897, grad_fn=<DivBackward0>)
# Epoch Number438
# Losstensor(51.2101, grad_fn=<DivBackward0>)
# Epoch Number439
# Losstensor(51.0318, grad_fn=<DivBackward0>)
# Epoch Number440
# Losstensor(50.8549, grad_fn=<DivBackward0>)
# Epoch Number441
# Losstensor(50.6795, grad_fn=<DivBackward0>)
# Epoch Number442
# Losstensor(50.5053, grad_fn=<DivBackward0>)
# Epoch Number443
# Losstensor(50.3324, grad_fn=<DivBackward0>)
# Epoch Number444
# Losstensor(50.1609, grad_fn=<DivBackward0>)
# Epoch Number445
# Losstensor(49.9907, grad_fn=<DivBackward0>)
# Epoch Number446
# Losstensor(49.8218, grad_fn=<DivBackward0>)
# Epoch Number447
# Losstensor(49.6542, grad_fn=<DivBackward0>)
# Epoch Number448
# Losstensor(49.4879, grad_fn=<DivBackward0>)
# Epoch Number449
# Losstensor(49.3228, grad_fn=<DivBackward0>)
# Epoch Number450
# Losstensor(49.1589, grad_fn=<DivBackward0>)
# Epoch Number451
# Losstensor(48.9963, grad_fn=<DivBackward0>)
# Epoch Number452
# Losstensor(48.8350, grad_fn=<DivBackward0>)
# Epoch Number453
# Losstensor(48.6748, grad_fn=<DivBackward0>)
# Epoch Number454
# Losstensor(48.5159, grad_fn=<DivBackward0>)
# Epoch Number455
# Losstensor(48.3581, grad_fn=<DivBackward0>)
# Epoch Number456
# Losstensor(48.2016, grad_fn=<DivBackward0>)
# Epoch Number457
# Losstensor(48.0462, grad_fn=<DivBackward0>)
# Epoch Number458
# Losstensor(47.8920, grad_fn=<DivBackward0>)
# Epoch Number459
# Losstensor(47.7390, grad_fn=<DivBackward0>)
# Epoch Number460
# Losstensor(47.5871, grad_fn=<DivBackward0>)
# Epoch Number461
# Losstensor(47.4363, grad_fn=<DivBackward0>)
# Epoch Number462
# Losstensor(47.2867, grad_fn=<DivBackward0>)
# Epoch Number463
# Losstensor(47.1381, grad_fn=<DivBackward0>)
# Epoch Number464
# Losstensor(46.9907, grad_fn=<DivBackward0>)
# Epoch Number465
# Losstensor(46.8444, grad_fn=<DivBackward0>)
# Epoch Number466
# Losstensor(46.6992, grad_fn=<DivBackward0>)
# Epoch Number467
# Losstensor(46.5550, grad_fn=<DivBackward0>)
# Epoch Number468
# Losstensor(46.4120, grad_fn=<DivBackward0>)
# Epoch Number469
# Losstensor(46.2699, grad_fn=<DivBackward0>)
# Epoch Number470
# Losstensor(46.1290, grad_fn=<DivBackward0>)
# Epoch Number471
# Losstensor(45.9891, grad_fn=<DivBackward0>)
# Epoch Number472
# Losstensor(45.8502, grad_fn=<DivBackward0>)
# Epoch Number473
# Losstensor(45.7123, grad_fn=<DivBackward0>)
# Epoch Number474
# Losstensor(45.5754, grad_fn=<DivBackward0>)
# Epoch Number475
# Losstensor(45.4395, grad_fn=<DivBackward0>)
# Epoch Number476
# Losstensor(45.3047, grad_fn=<DivBackward0>)
# Epoch Number477
# Losstensor(45.1708, grad_fn=<DivBackward0>)
# Epoch Number478
# Losstensor(45.0379, grad_fn=<DivBackward0>)
# Epoch Number479
# Losstensor(44.9060, grad_fn=<DivBackward0>)
# Epoch Number480
# Losstensor(44.7751, grad_fn=<DivBackward0>)
# Epoch Number481
# Losstensor(44.6451, grad_fn=<DivBackward0>)
# Epoch Number482
# Losstensor(44.5160, grad_fn=<DivBackward0>)
# Epoch Number483
# Losstensor(44.3879, grad_fn=<DivBackward0>)
# Epoch Number484
# Losstensor(44.2607, grad_fn=<DivBackward0>)
# Epoch Number485
# Losstensor(44.1344, grad_fn=<DivBackward0>)
# Epoch Number486
# Losstensor(44.0091, grad_fn=<DivBackward0>)
# Epoch Number487
# Losstensor(43.8846, grad_fn=<DivBackward0>)
# Epoch Number488
# Losstensor(43.7610, grad_fn=<DivBackward0>)
# Epoch Number489
# Losstensor(43.6384, grad_fn=<DivBackward0>)
# Epoch Number490
# Losstensor(43.5167, grad_fn=<DivBackward0>)
# Epoch Number491
# Losstensor(43.3957, grad_fn=<DivBackward0>)
# Epoch Number492
# Losstensor(43.2757, grad_fn=<DivBackward0>)
# Epoch Number493
# Losstensor(43.1566, grad_fn=<DivBackward0>)
# Epoch Number494
# Losstensor(43.0382, grad_fn=<DivBackward0>)
# Epoch Number495
# Losstensor(42.9207, grad_fn=<DivBackward0>)
# Epoch Number496
# Losstensor(42.8042, grad_fn=<DivBackward0>)
# Epoch Number497
# Losstensor(42.6883, grad_fn=<DivBackward0>)
# Epoch Number498
# Losstensor(42.5734, grad_fn=<DivBackward0>)
# Epoch Number499
# Losstensor(42.4592, grad_fn=<DivBackward0>)
# Epoch Number500
# Losstensor(42.3458, grad_fn=<DivBackward0>)
# Epoch Number501
# Losstensor(42.2333, grad_fn=<DivBackward0>)
# Epoch Number502
# Losstensor(42.1215, grad_fn=<DivBackward0>)
# Epoch Number503
# Losstensor(42.0105, grad_fn=<DivBackward0>)
# Epoch Number504
# Losstensor(41.9003, grad_fn=<DivBackward0>)
# Epoch Number505
# Losstensor(41.7909, grad_fn=<DivBackward0>)
# Epoch Number506
# Losstensor(41.6823, grad_fn=<DivBackward0>)
# Epoch Number507
# Losstensor(41.5744, grad_fn=<DivBackward0>)
# Epoch Number508
# Losstensor(41.4673, grad_fn=<DivBackward0>)
# Epoch Number509
# Losstensor(41.3609, grad_fn=<DivBackward0>)
# Epoch Number510
# Losstensor(41.2553, grad_fn=<DivBackward0>)
# Epoch Number511
# Losstensor(41.1504, grad_fn=<DivBackward0>)
# Epoch Number512
# Losstensor(41.0462, grad_fn=<DivBackward0>)
# Epoch Number513
# Losstensor(40.9428, grad_fn=<DivBackward0>)
# Epoch Number514
# Losstensor(40.8401, grad_fn=<DivBackward0>)
# Epoch Number515
# Losstensor(40.7381, grad_fn=<DivBackward0>)
# Epoch Number516
# Losstensor(40.6368, grad_fn=<DivBackward0>)
# Epoch Number517
# Losstensor(40.5362, grad_fn=<DivBackward0>)
# Epoch Number518
# Losstensor(40.4363, grad_fn=<DivBackward0>)
# Epoch Number519
# Losstensor(40.3371, grad_fn=<DivBackward0>)
# Epoch Number520
# Losstensor(40.2385, grad_fn=<DivBackward0>)
# Epoch Number521
# Losstensor(40.1407, grad_fn=<DivBackward0>)
# Epoch Number522
# Losstensor(40.0435, grad_fn=<DivBackward0>)
# Epoch Number523
# Losstensor(39.9470, grad_fn=<DivBackward0>)
# Epoch Number524
# Losstensor(39.8511, grad_fn=<DivBackward0>)
# Epoch Number525
# Losstensor(39.7559, grad_fn=<DivBackward0>)
# Epoch Number526
# Losstensor(39.6613, grad_fn=<DivBackward0>)
# Epoch Number527
# Losstensor(39.5674, grad_fn=<DivBackward0>)
# Epoch Number528
# Losstensor(39.4741, grad_fn=<DivBackward0>)
# Epoch Number529
# Losstensor(39.3815, grad_fn=<DivBackward0>)
# Epoch Number530
# Losstensor(39.2895, grad_fn=<DivBackward0>)
# Epoch Number531
# Losstensor(39.1981, grad_fn=<DivBackward0>)
# Epoch Number532
# Losstensor(39.1073, grad_fn=<DivBackward0>)
# Epoch Number533
# Losstensor(39.0171, grad_fn=<DivBackward0>)
# Epoch Number534
# Losstensor(38.9276, grad_fn=<DivBackward0>)
# Epoch Number535
# Losstensor(38.8386, grad_fn=<DivBackward0>)
# Epoch Number536
# Losstensor(38.7502, grad_fn=<DivBackward0>)
# Epoch Number537
# Losstensor(38.6625, grad_fn=<DivBackward0>)
# Epoch Number538
# Losstensor(38.5753, grad_fn=<DivBackward0>)
# Epoch Number539
# Losstensor(38.4887, grad_fn=<DivBackward0>)
# Epoch Number540
# Losstensor(38.4026, grad_fn=<DivBackward0>)
# Epoch Number541
# Losstensor(38.3172, grad_fn=<DivBackward0>)
# Epoch Number542
# Losstensor(38.2323, grad_fn=<DivBackward0>)
# Epoch Number543
# Losstensor(38.1480, grad_fn=<DivBackward0>)
# Epoch Number544
# Losstensor(38.0641, grad_fn=<DivBackward0>)
# Epoch Number545
# Losstensor(37.9810, grad_fn=<DivBackward0>)
# Epoch Number546
# Losstensor(37.8983, grad_fn=<DivBackward0>)
# Epoch Number547
# Losstensor(37.8161, grad_fn=<DivBackward0>)
# Epoch Number548
# Losstensor(37.7345, grad_fn=<DivBackward0>)
# Epoch Number549
# Losstensor(37.6535, grad_fn=<DivBackward0>)
# Epoch Number550
# Losstensor(37.5730, grad_fn=<DivBackward0>)
# Epoch Number551
# Losstensor(37.4930, grad_fn=<DivBackward0>)
# Epoch Number552
# Losstensor(37.4135, grad_fn=<DivBackward0>)
# Epoch Number553
# Losstensor(37.3346, grad_fn=<DivBackward0>)
# Epoch Number554
# Losstensor(37.2561, grad_fn=<DivBackward0>)
# Epoch Number555
# Losstensor(37.1782, grad_fn=<DivBackward0>)
# Epoch Number556
# Losstensor(37.1007, grad_fn=<DivBackward0>)
# Epoch Number557
# Losstensor(37.0238, grad_fn=<DivBackward0>)
# Epoch Number558
# Losstensor(36.9473, grad_fn=<DivBackward0>)
# Epoch Number559
# Losstensor(36.8714, grad_fn=<DivBackward0>)
# Epoch Number560
# Losstensor(36.7959, grad_fn=<DivBackward0>)
# Epoch Number561
# Losstensor(36.7210, grad_fn=<DivBackward0>)
# Epoch Number562
# Losstensor(36.6465, grad_fn=<DivBackward0>)
# Epoch Number563
# Losstensor(36.5724, grad_fn=<DivBackward0>)
# Epoch Number564
# Losstensor(36.4989, grad_fn=<DivBackward0>)
# Epoch Number565
# Losstensor(36.4258, grad_fn=<DivBackward0>)
# Epoch Number566
# Losstensor(36.3532, grad_fn=<DivBackward0>)
# Epoch Number567
# Losstensor(36.2811, grad_fn=<DivBackward0>)
# Epoch Number568
# Losstensor(36.2094, grad_fn=<DivBackward0>)
# Epoch Number569
# Losstensor(36.1381, grad_fn=<DivBackward0>)
# Epoch Number570
# Losstensor(36.0674, grad_fn=<DivBackward0>)
# Epoch Number571
# Losstensor(35.9970, grad_fn=<DivBackward0>)
# Epoch Number572
# Losstensor(35.9271, grad_fn=<DivBackward0>)
# Epoch Number573
# Losstensor(35.8576, grad_fn=<DivBackward0>)
# Epoch Number574
# Losstensor(35.7886, grad_fn=<DivBackward0>)
# Epoch Number575
# Losstensor(35.7200, grad_fn=<DivBackward0>)
# Epoch Number576
# Losstensor(35.6518, grad_fn=<DivBackward0>)
# Epoch Number577
# Losstensor(35.5841, grad_fn=<DivBackward0>)
# Epoch Number578
# Losstensor(35.5167, grad_fn=<DivBackward0>)
# Epoch Number579
# Losstensor(35.4498, grad_fn=<DivBackward0>)
# Epoch Number580
# Losstensor(35.3833, grad_fn=<DivBackward0>)
# Epoch Number581
# Losstensor(35.3173, grad_fn=<DivBackward0>)
# Epoch Number582
# Losstensor(35.2516, grad_fn=<DivBackward0>)
# Epoch Number583
# Losstensor(35.1863, grad_fn=<DivBackward0>)
# Epoch Number584
# Losstensor(35.1215, grad_fn=<DivBackward0>)
# Epoch Number585
# Losstensor(35.0570, grad_fn=<DivBackward0>)
# Epoch Number586
# Losstensor(34.9929, grad_fn=<DivBackward0>)
# Epoch Number587
# Losstensor(34.9292, grad_fn=<DivBackward0>)
# Epoch Number588
# Losstensor(34.8659, grad_fn=<DivBackward0>)
# Epoch Number589
# Losstensor(34.8030, grad_fn=<DivBackward0>)
# Epoch Number590
# Losstensor(34.7405, grad_fn=<DivBackward0>)
# Epoch Number591
# Losstensor(34.6783, grad_fn=<DivBackward0>)
# Epoch Number592
# Losstensor(34.6165, grad_fn=<DivBackward0>)
# Epoch Number593
# Losstensor(34.5551, grad_fn=<DivBackward0>)
# Epoch Number594
# Losstensor(34.4941, grad_fn=<DivBackward0>)
# Epoch Number595
# Losstensor(34.4334, grad_fn=<DivBackward0>)
# Epoch Number596
# Losstensor(34.3732, grad_fn=<DivBackward0>)
# Epoch Number597
# Losstensor(34.3132, grad_fn=<DivBackward0>)
# Epoch Number598
# Losstensor(34.2536, grad_fn=<DivBackward0>)
# Epoch Number599
# Losstensor(34.1944, grad_fn=<DivBackward0>)
# Epoch Number600
# Losstensor(34.1355, grad_fn=<DivBackward0>)
# Epoch Number601
# Losstensor(34.0770, grad_fn=<DivBackward0>)
# Epoch Number602
# Losstensor(34.0188, grad_fn=<DivBackward0>)
# Epoch Number603
# Losstensor(33.9610, grad_fn=<DivBackward0>)
# Epoch Number604
# Losstensor(33.9035, grad_fn=<DivBackward0>)
# Epoch Number605
# Losstensor(33.8463, grad_fn=<DivBackward0>)
# Epoch Number606
# Losstensor(33.7895, grad_fn=<DivBackward0>)
# Epoch Number607
# Losstensor(33.7330, grad_fn=<DivBackward0>)
# Epoch Number608
# Losstensor(33.6769, grad_fn=<DivBackward0>)
# Epoch Number609
# Losstensor(33.6211, grad_fn=<DivBackward0>)
# Epoch Number610
# Losstensor(33.5656, grad_fn=<DivBackward0>)
# Epoch Number611
# Losstensor(33.5104, grad_fn=<DivBackward0>)
# Epoch Number612
# Losstensor(33.4555, grad_fn=<DivBackward0>)
# Epoch Number613
# Losstensor(33.4010, grad_fn=<DivBackward0>)
# Epoch Number614
# Losstensor(33.3468, grad_fn=<DivBackward0>)
# Epoch Number615
# Losstensor(33.2929, grad_fn=<DivBackward0>)
# Epoch Number616
# Losstensor(33.2393, grad_fn=<DivBackward0>)
# Epoch Number617
# Losstensor(33.1860, grad_fn=<DivBackward0>)
# Epoch Number618
# Losstensor(33.1330, grad_fn=<DivBackward0>)
# Epoch Number619
# Losstensor(33.0804, grad_fn=<DivBackward0>)
# Epoch Number620
# Losstensor(33.0280, grad_fn=<DivBackward0>)
# Epoch Number621
# Losstensor(32.9759, grad_fn=<DivBackward0>)
# Epoch Number622
# Losstensor(32.9241, grad_fn=<DivBackward0>)
# Epoch Number623
# Losstensor(32.8726, grad_fn=<DivBackward0>)
# Epoch Number624
# Losstensor(32.8214, grad_fn=<DivBackward0>)
# Epoch Number625
# Losstensor(32.7705, grad_fn=<DivBackward0>)
# Epoch Number626
# Losstensor(32.7199, grad_fn=<DivBackward0>)
# Epoch Number627
# Losstensor(32.6696, grad_fn=<DivBackward0>)
# Epoch Number628
# Losstensor(32.6195, grad_fn=<DivBackward0>)
# Epoch Number629
# Losstensor(32.5697, grad_fn=<DivBackward0>)
# Epoch Number630
# Losstensor(32.5202, grad_fn=<DivBackward0>)
# Epoch Number631
# Losstensor(32.4711, grad_fn=<DivBackward0>)
# Epoch Number632
# Losstensor(32.4221, grad_fn=<DivBackward0>)
# Epoch Number633
# Losstensor(32.3734, grad_fn=<DivBackward0>)
# Epoch Number634
# Losstensor(32.3250, grad_fn=<DivBackward0>)
# Epoch Number635
# Losstensor(32.2769, grad_fn=<DivBackward0>)
# Epoch Number636
# Losstensor(32.2291, grad_fn=<DivBackward0>)
# Epoch Number637
# Losstensor(32.1814, grad_fn=<DivBackward0>)
# Epoch Number638
# Losstensor(32.1341, grad_fn=<DivBackward0>)
# Epoch Number639
# Losstensor(32.0870, grad_fn=<DivBackward0>)
# Epoch Number640
# Losstensor(32.0402, grad_fn=<DivBackward0>)
# Epoch Number641
# Losstensor(31.9936, grad_fn=<DivBackward0>)
# Epoch Number642
# Losstensor(31.9473, grad_fn=<DivBackward0>)
# Epoch Number643
# Losstensor(31.9013, grad_fn=<DivBackward0>)
# Epoch Number644
# Losstensor(31.8555, grad_fn=<DivBackward0>)
# Epoch Number645
# Losstensor(31.8099, grad_fn=<DivBackward0>)
# Epoch Number646
# Losstensor(31.7646, grad_fn=<DivBackward0>)
# Epoch Number647
# Losstensor(31.7195, grad_fn=<DivBackward0>)
# Epoch Number648
# Losstensor(31.6747, grad_fn=<DivBackward0>)
# Epoch Number649
# Losstensor(31.6301, grad_fn=<DivBackward0>)
# Epoch Number650
# Losstensor(31.5858, grad_fn=<DivBackward0>)
# Epoch Number651
# Losstensor(31.5417, grad_fn=<DivBackward0>)
# Epoch Number652
# Losstensor(31.4978, grad_fn=<DivBackward0>)
# Epoch Number653
# Losstensor(31.4541, grad_fn=<DivBackward0>)
# Epoch Number654
# Losstensor(31.4107, grad_fn=<DivBackward0>)
# Epoch Number655
# Losstensor(31.3676, grad_fn=<DivBackward0>)
# Epoch Number656
# Losstensor(31.3246, grad_fn=<DivBackward0>)
# Epoch Number657
# Losstensor(31.2819, grad_fn=<DivBackward0>)
# Epoch Number658
# Losstensor(31.2394, grad_fn=<DivBackward0>)
# Epoch Number659
# Losstensor(31.1971, grad_fn=<DivBackward0>)
# Epoch Number660
# Losstensor(31.1551, grad_fn=<DivBackward0>)
# Epoch Number661
# Losstensor(31.1133, grad_fn=<DivBackward0>)
# Epoch Number662
# Losstensor(31.0717, grad_fn=<DivBackward0>)
# Epoch Number663
# Losstensor(31.0303, grad_fn=<DivBackward0>)
# Epoch Number664
# Losstensor(30.9891, grad_fn=<DivBackward0>)
# Epoch Number665
# Losstensor(30.9481, grad_fn=<DivBackward0>)
# Epoch Number666
# Losstensor(30.9074, grad_fn=<DivBackward0>)
# Epoch Number667
# Losstensor(30.8668, grad_fn=<DivBackward0>)
# Epoch Number668
# Losstensor(30.8265, grad_fn=<DivBackward0>)
# Epoch Number669
# Losstensor(30.7864, grad_fn=<DivBackward0>)
# Epoch Number670
# Losstensor(30.7465, grad_fn=<DivBackward0>)
# Epoch Number671
# Losstensor(30.7068, grad_fn=<DivBackward0>)
# Epoch Number672
# Losstensor(30.6673, grad_fn=<DivBackward0>)
# Epoch Number673
# Losstensor(30.6279, grad_fn=<DivBackward0>)
# Epoch Number674
# Losstensor(30.5888, grad_fn=<DivBackward0>)
# Epoch Number675
# Losstensor(30.5499, grad_fn=<DivBackward0>)
# Epoch Number676
# Losstensor(30.5112, grad_fn=<DivBackward0>)
# Epoch Number677
# Losstensor(30.4727, grad_fn=<DivBackward0>)
# Epoch Number678
# Losstensor(30.4343, grad_fn=<DivBackward0>)
# Epoch Number679
# Losstensor(30.3962, grad_fn=<DivBackward0>)
# Epoch Number680
# Losstensor(30.3583, grad_fn=<DivBackward0>)
# Epoch Number681
# Losstensor(30.3205, grad_fn=<DivBackward0>)
# Epoch Number682
# Losstensor(30.2830, grad_fn=<DivBackward0>)
# Epoch Number683
# Losstensor(30.2456, grad_fn=<DivBackward0>)
# Epoch Number684
# Losstensor(30.2084, grad_fn=<DivBackward0>)
# Epoch Number685
# Losstensor(30.1714, grad_fn=<DivBackward0>)
# Epoch Number686
# Losstensor(30.1346, grad_fn=<DivBackward0>)
# Epoch Number687
# Losstensor(30.0980, grad_fn=<DivBackward0>)
# Epoch Number688
# Losstensor(30.0615, grad_fn=<DivBackward0>)
# Epoch Number689
# Losstensor(30.0253, grad_fn=<DivBackward0>)
# Epoch Number690
# Losstensor(29.9892, grad_fn=<DivBackward0>)
# Epoch Number691
# Losstensor(29.9533, grad_fn=<DivBackward0>)
# Epoch Number692
# Losstensor(29.9175, grad_fn=<DivBackward0>)
# Epoch Number693
# Losstensor(29.8819, grad_fn=<DivBackward0>)
# Epoch Number694
# Losstensor(29.8465, grad_fn=<DivBackward0>)
# Epoch Number695
# Losstensor(29.8113, grad_fn=<DivBackward0>)
# Epoch Number696
# Losstensor(29.7763, grad_fn=<DivBackward0>)
# Epoch Number697
# Losstensor(29.7414, grad_fn=<DivBackward0>)
# Epoch Number698
# Losstensor(29.7067, grad_fn=<DivBackward0>)
# Epoch Number699
# Losstensor(29.6721, grad_fn=<DivBackward0>)
# Epoch Number700
# Losstensor(29.6377, grad_fn=<DivBackward0>)
# Epoch Number701
# Losstensor(29.6035, grad_fn=<DivBackward0>)
# Epoch Number702
# Losstensor(29.5695, grad_fn=<DivBackward0>)
# Epoch Number703
# Losstensor(29.5356, grad_fn=<DivBackward0>)
# Epoch Number704
# Losstensor(29.5018, grad_fn=<DivBackward0>)
# Epoch Number705
# Losstensor(29.4683, grad_fn=<DivBackward0>)
# Epoch Number706
# Losstensor(29.4349, grad_fn=<DivBackward0>)
# Epoch Number707
# Losstensor(29.4016, grad_fn=<DivBackward0>)
# Epoch Number708
# Losstensor(29.3685, grad_fn=<DivBackward0>)
# Epoch Number709
# Losstensor(29.3356, grad_fn=<DivBackward0>)
# Epoch Number710
# Losstensor(29.3028, grad_fn=<DivBackward0>)
# Epoch Number711
# Losstensor(29.2702, grad_fn=<DivBackward0>)
# Epoch Number712
# Losstensor(29.2377, grad_fn=<DivBackward0>)
# Epoch Number713
# Losstensor(29.2054, grad_fn=<DivBackward0>)
# Epoch Number714
# Losstensor(29.1732, grad_fn=<DivBackward0>)
# Epoch Number715
# Losstensor(29.1412, grad_fn=<DivBackward0>)
# Epoch Number716
# Losstensor(29.1093, grad_fn=<DivBackward0>)
# Epoch Number717
# Losstensor(29.0776, grad_fn=<DivBackward0>)
# Epoch Number718
# Losstensor(29.0460, grad_fn=<DivBackward0>)
# Epoch Number719
# Losstensor(29.0146, grad_fn=<DivBackward0>)
# Epoch Number720
# Losstensor(28.9833, grad_fn=<DivBackward0>)
# Epoch Number721
# Losstensor(28.9521, grad_fn=<DivBackward0>)
# Epoch Number722
# Losstensor(28.9211, grad_fn=<DivBackward0>)
# Epoch Number723
# Losstensor(28.8903, grad_fn=<DivBackward0>)
# Epoch Number724
# Losstensor(28.8595, grad_fn=<DivBackward0>)
# Epoch Number725
# Losstensor(28.8290, grad_fn=<DivBackward0>)
# Epoch Number726
# Losstensor(28.7985, grad_fn=<DivBackward0>)
# Epoch Number727
# Losstensor(28.7682, grad_fn=<DivBackward0>)
# Epoch Number728
# Losstensor(28.7380, grad_fn=<DivBackward0>)
# Epoch Number729
# Losstensor(28.7080, grad_fn=<DivBackward0>)
# Epoch Number730
# Losstensor(28.6781, grad_fn=<DivBackward0>)
# Epoch Number731
# Losstensor(28.6484, grad_fn=<DivBackward0>)
# Epoch Number732
# Losstensor(28.6187, grad_fn=<DivBackward0>)
# Epoch Number733
# Losstensor(28.5892, grad_fn=<DivBackward0>)
# Epoch Number734
# Losstensor(28.5599, grad_fn=<DivBackward0>)
# Epoch Number735
# Losstensor(28.5306, grad_fn=<DivBackward0>)
# Epoch Number736
# Losstensor(28.5015, grad_fn=<DivBackward0>)
# Epoch Number737
# Losstensor(28.4726, grad_fn=<DivBackward0>)
# Epoch Number738
# Losstensor(28.4437, grad_fn=<DivBackward0>)
# Epoch Number739
# Losstensor(28.4150, grad_fn=<DivBackward0>)
# Epoch Number740
# Losstensor(28.3864, grad_fn=<DivBackward0>)
# Epoch Number741
# Losstensor(28.3579, grad_fn=<DivBackward0>)
# Epoch Number742
# Losstensor(28.3295, grad_fn=<DivBackward0>)
# Epoch Number743
# Losstensor(28.3013, grad_fn=<DivBackward0>)
# Epoch Number744
# Losstensor(28.2733, grad_fn=<DivBackward0>)
# Epoch Number745
# Losstensor(28.2453, grad_fn=<DivBackward0>)
# Epoch Number746
# Losstensor(28.2174, grad_fn=<DivBackward0>)
# Epoch Number747
# Losstensor(28.1897, grad_fn=<DivBackward0>)
# Epoch Number748
# Losstensor(28.1621, grad_fn=<DivBackward0>)
# Epoch Number749
# Losstensor(28.1346, grad_fn=<DivBackward0>)
# Epoch Number750
# Losstensor(28.1072, grad_fn=<DivBackward0>)
# Epoch Number751
# Losstensor(28.0799, grad_fn=<DivBackward0>)
# Epoch Number752
# Losstensor(28.0528, grad_fn=<DivBackward0>)
# Epoch Number753
# Losstensor(28.0258, grad_fn=<DivBackward0>)
# Epoch Number754
# Losstensor(27.9989, grad_fn=<DivBackward0>)
# Epoch Number755
# Losstensor(27.9721, grad_fn=<DivBackward0>)
# Epoch Number756
# Losstensor(27.9454, grad_fn=<DivBackward0>)
# Epoch Number757
# Losstensor(27.9188, grad_fn=<DivBackward0>)
# Epoch Number758
# Losstensor(27.8924, grad_fn=<DivBackward0>)
# Epoch Number759
# Losstensor(27.8660, grad_fn=<DivBackward0>)
# Epoch Number760
# Losstensor(27.8398, grad_fn=<DivBackward0>)
# Epoch Number761
# Losstensor(27.8137, grad_fn=<DivBackward0>)
# Epoch Number762
# Losstensor(27.7877, grad_fn=<DivBackward0>)
# Epoch Number763
# Losstensor(27.7618, grad_fn=<DivBackward0>)
# Epoch Number764
# Losstensor(27.7360, grad_fn=<DivBackward0>)
# Epoch Number765
# Losstensor(27.7103, grad_fn=<DivBackward0>)
# Epoch Number766
# Losstensor(27.6847, grad_fn=<DivBackward0>)
# Epoch Number767
# Losstensor(27.6592, grad_fn=<DivBackward0>)
# Epoch Number768
# Losstensor(27.6339, grad_fn=<DivBackward0>)
# Epoch Number769
# Losstensor(27.6086, grad_fn=<DivBackward0>)
# Epoch Number770
# Losstensor(27.5835, grad_fn=<DivBackward0>)
# Epoch Number771
# Losstensor(27.5584, grad_fn=<DivBackward0>)
# Epoch Number772
# Losstensor(27.5334, grad_fn=<DivBackward0>)
# Epoch Number773
# Losstensor(27.5086, grad_fn=<DivBackward0>)
# Epoch Number774
# Losstensor(27.4838, grad_fn=<DivBackward0>)
# Epoch Number775
# Losstensor(27.4592, grad_fn=<DivBackward0>)
# Epoch Number776
# Losstensor(27.4346, grad_fn=<DivBackward0>)
# Epoch Number777
# Losstensor(27.4102, grad_fn=<DivBackward0>)
# Epoch Number778
# Losstensor(27.3859, grad_fn=<DivBackward0>)
# Epoch Number779
# Losstensor(27.3616, grad_fn=<DivBackward0>)
# Epoch Number780
# Losstensor(27.3375, grad_fn=<DivBackward0>)
# Epoch Number781
# Losstensor(27.3134, grad_fn=<DivBackward0>)
# Epoch Number782
# Losstensor(27.2895, grad_fn=<DivBackward0>)
# Epoch Number783
# Losstensor(27.2656, grad_fn=<DivBackward0>)
# Epoch Number784
# Losstensor(27.2418, grad_fn=<DivBackward0>)
# Epoch Number785
# Losstensor(27.2182, grad_fn=<DivBackward0>)
# Epoch Number786
# Losstensor(27.1946, grad_fn=<DivBackward0>)
# Epoch Number787
# Losstensor(27.1711, grad_fn=<DivBackward0>)
# Epoch Number788
# Losstensor(27.1477, grad_fn=<DivBackward0>)
# Epoch Number789
# Losstensor(27.1244, grad_fn=<DivBackward0>)
# Epoch Number790
# Losstensor(27.1012, grad_fn=<DivBackward0>)
# Epoch Number791
# Losstensor(27.0781, grad_fn=<DivBackward0>)
# Epoch Number792
# Losstensor(27.0551, grad_fn=<DivBackward0>)
# Epoch Number793
# Losstensor(27.0322, grad_fn=<DivBackward0>)
# Epoch Number794
# Losstensor(27.0093, grad_fn=<DivBackward0>)
# Epoch Number795
# Losstensor(26.9866, grad_fn=<DivBackward0>)
# Epoch Number796
# ...
# Epoch Number1738
# Losstensor(19.9412, grad_fn=<DivBackward0>)
# Epoch Number1739
# Losstensor(19.9395, grad_fn=<DivBackward0>)
# Epoch Number1740
# Losstensor(19.9378, grad_fn=<DivBackward0>)
# Epoch Number1741
# Losstensor(19.9360, grad_fn=<DivBackward0>)
# Epoch Number1742
# Losstensor(19.9343, grad_fn=<DivBackward0>)
# Epoch Number1743
# Losstensor(19.9326, grad_fn=<DivBackward0>)
# Epoch Number1744
# Losstensor(19.9309, grad_fn=<DivBackward0>)
# Epoch Number1745
# Losstensor(19.9292, grad_fn=<DivBackward0>)
# Epoch Number1746
# Losstensor(19.9275, grad_fn=<DivBackward0>)
# Epoch Number1747
# Losstensor(19.9258, grad_fn=<DivBackward0>)
# Epoch Number1748
# Losstensor(19.9241, grad_fn=<DivBackward0>)
# Epoch Number1749
# Losstensor(19.9224, grad_fn=<DivBackward0>)
# Epoch Number1750
# Losstensor(19.9208, grad_fn=<DivBackward0>)
# Epoch Number1751
# Losstensor(19.9191, grad_fn=<DivBackward0>)
# Epoch Number1752
# Losstensor(19.9174, grad_fn=<DivBackward0>)
# Epoch Number1753
# Losstensor(19.9158, grad_fn=<DivBackward0>)
# Epoch Number1754
# Losstensor(19.9141, grad_fn=<DivBackward0>)
# Epoch Number1755
# Losstensor(19.9124, grad_fn=<DivBackward0>)
# Epoch Number1756
# Losstensor(19.9108, grad_fn=<DivBackward0>)
# Epoch Number1757
# Losstensor(19.9091, grad_fn=<DivBackward0>)
# Epoch Number1758
# Losstensor(19.9075, grad_fn=<DivBackward0>)
# Epoch Number1759
# Losstensor(19.9058, grad_fn=<DivBackward0>)
# Epoch Number1760
# Losstensor(19.9042, grad_fn=<DivBackward0>)
# Epoch Number1761
# Losstensor(19.9026, grad_fn=<DivBackward0>)
# Epoch Number1762
# Losstensor(19.9009, grad_fn=<DivBackward0>)
# Epoch Number1763
# Losstensor(19.8993, grad_fn=<DivBackward0>)
# Epoch Number1764
# Losstensor(19.8977, grad_fn=<DivBackward0>)
# Epoch Number1765
# Losstensor(19.8960, grad_fn=<DivBackward0>)
# Epoch Number1766
# Losstensor(19.8944, grad_fn=<DivBackward0>)
# Epoch Number1767
# Losstensor(19.8928, grad_fn=<DivBackward0>)
# Epoch Number1768
# Losstensor(19.8912, grad_fn=<DivBackward0>)
# Epoch Number1769
# Losstensor(19.8896, grad_fn=<DivBackward0>)
# Epoch Number1770
# Losstensor(19.8880, grad_fn=<DivBackward0>)
# Epoch Number1771
# Losstensor(19.8864, grad_fn=<DivBackward0>)
# Epoch Number1772
# Losstensor(19.8848, grad_fn=<DivBackward0>)
# Epoch Number1773
# Losstensor(19.8833, grad_fn=<DivBackward0>)
# Epoch Number1774
# Losstensor(19.8817, grad_fn=<DivBackward0>)
# Epoch Number1775
# Losstensor(19.8801, grad_fn=<DivBackward0>)
# Epoch Number1776
# Losstensor(19.8785, grad_fn=<DivBackward0>)
# Epoch Number1777
# Losstensor(19.8770, grad_fn=<DivBackward0>)
# Epoch Number1778
# Losstensor(19.8754, grad_fn=<DivBackward0>)
# Epoch Number1779
# Losstensor(19.8738, grad_fn=<DivBackward0>)
# Epoch Number1780
# Losstensor(19.8722, grad_fn=<DivBackward0>)
# Epoch Number1781
# Losstensor(19.8707, grad_fn=<DivBackward0>)
# Epoch Number1782
# Losstensor(19.8692, grad_fn=<DivBackward0>)
# Epoch Number1783
# Losstensor(19.8676, grad_fn=<DivBackward0>)
# Epoch Number1784
# Losstensor(19.8661, grad_fn=<DivBackward0>)
# Epoch Number1785
# Losstensor(19.8645, grad_fn=<DivBackward0>)
# Epoch Number1786
# Losstensor(19.8630, grad_fn=<DivBackward0>)
# Epoch Number1787
# Losstensor(19.8615, grad_fn=<DivBackward0>)
# Epoch Number1788
# Losstensor(19.8599, grad_fn=<DivBackward0>)
# Epoch Number1789
# Losstensor(19.8584, grad_fn=<DivBackward0>)
# Epoch Number1790
# Losstensor(19.8569, grad_fn=<DivBackward0>)
# Epoch Number1791
# Losstensor(19.8553, grad_fn=<DivBackward0>)
# Epoch Number1792
# Losstensor(19.8538, grad_fn=<DivBackward0>)
# Epoch Number1793
# Losstensor(19.8523, grad_fn=<DivBackward0>)
# Epoch Number1794
# Losstensor(19.8508, grad_fn=<DivBackward0>)
# Epoch Number1795
# Losstensor(19.8493, grad_fn=<DivBackward0>)
# Epoch Number1796
# Losstensor(19.8478, grad_fn=<DivBackward0>)
# Epoch Number1797
# Losstensor(19.8463, grad_fn=<DivBackward0>)
# Epoch Number1798
# Losstensor(19.8449, grad_fn=<DivBackward0>)
# Epoch Number1799
# Losstensor(19.8433, grad_fn=<DivBackward0>)
# Epoch Number1800
# Losstensor(19.8419, grad_fn=<DivBackward0>)
# Epoch Number1801
# Losstensor(19.8404, grad_fn=<DivBackward0>)
# Epoch Number1802
# Losstensor(19.8389, grad_fn=<DivBackward0>)
# Epoch Number1803
# Losstensor(19.8375, grad_fn=<DivBackward0>)
# Epoch Number1804
# Losstensor(19.8360, grad_fn=<DivBackward0>)
# Epoch Number1805
# Losstensor(19.8345, grad_fn=<DivBackward0>)
# Epoch Number1806
# Losstensor(19.8331, grad_fn=<DivBackward0>)
# Epoch Number1807
# Losstensor(19.8316, grad_fn=<DivBackward0>)
# Epoch Number1808
# Losstensor(19.8301, grad_fn=<DivBackward0>)
# Epoch Number1809
# Losstensor(19.8287, grad_fn=<DivBackward0>)
# Epoch Number1810
# Losstensor(19.8272, grad_fn=<DivBackward0>)
# Epoch Number1811
# Losstensor(19.8258, grad_fn=<DivBackward0>)
# Epoch Number1812
# Losstensor(19.8244, grad_fn=<DivBackward0>)
# Epoch Number1813
# Losstensor(19.8229, grad_fn=<DivBackward0>)
# Epoch Number1814
# Losstensor(19.8215, grad_fn=<DivBackward0>)
# Epoch Number1815
# Losstensor(19.8201, grad_fn=<DivBackward0>)
# Epoch Number1816
# Losstensor(19.8186, grad_fn=<DivBackward0>)
# Epoch Number1817
# Losstensor(19.8172, grad_fn=<DivBackward0>)
# Epoch Number1818
# Losstensor(19.8158, grad_fn=<DivBackward0>)
# Epoch Number1819
# Losstensor(19.8144, grad_fn=<DivBackward0>)
# Epoch Number1820
# Losstensor(19.8130, grad_fn=<DivBackward0>)
# Epoch Number1821
# Losstensor(19.8115, grad_fn=<DivBackward0>)
# Epoch Number1822
# Losstensor(19.8101, grad_fn=<DivBackward0>)
# Epoch Number1823
# Losstensor(19.8088, grad_fn=<DivBackward0>)
# Epoch Number1824
# Losstensor(19.8073, grad_fn=<DivBackward0>)
# Epoch Number1825
# Losstensor(19.8060, grad_fn=<DivBackward0>)
# Epoch Number1826
# Losstensor(19.8046, grad_fn=<DivBackward0>)
# Epoch Number1827
# Losstensor(19.8032, grad_fn=<DivBackward0>)
# Epoch Number1828
# Losstensor(19.8018, grad_fn=<DivBackward0>)
# Epoch Number1829
# Losstensor(19.8004, grad_fn=<DivBackward0>)
# Epoch Number1830
# Losstensor(19.7990, grad_fn=<DivBackward0>)
# Epoch Number1831
# Losstensor(19.7977, grad_fn=<DivBackward0>)
# Epoch Number1832
# Losstensor(19.7963, grad_fn=<DivBackward0>)
# Epoch Number1833
# Losstensor(19.7949, grad_fn=<DivBackward0>)
# Epoch Number1834
# Losstensor(19.7936, grad_fn=<DivBackward0>)
# Epoch Number1835
# Losstensor(19.7922, grad_fn=<DivBackward0>)
# Epoch Number1836
# Losstensor(19.7908, grad_fn=<DivBackward0>)
# Epoch Number1837
# Losstensor(19.7895, grad_fn=<DivBackward0>)
# Epoch Number1838
# Losstensor(19.7881, grad_fn=<DivBackward0>)
# Epoch Number1839
# Losstensor(19.7868, grad_fn=<DivBackward0>)
# Epoch Number1840
# Losstensor(19.7854, grad_fn=<DivBackward0>)
# Epoch Number1841
# Losstensor(19.7841, grad_fn=<DivBackward0>)
# Epoch Number1842
# Losstensor(19.7828, grad_fn=<DivBackward0>)
# Epoch Number1843
# Losstensor(19.7814, grad_fn=<DivBackward0>)
# Epoch Number1844
# Losstensor(19.7801, grad_fn=<DivBackward0>)
# Epoch Number1845
# Losstensor(19.7788, grad_fn=<DivBackward0>)
# Epoch Number1846
# Losstensor(19.7775, grad_fn=<DivBackward0>)
# Epoch Number1847
# Losstensor(19.7761, grad_fn=<DivBackward0>)
# Epoch Number1848
# Losstensor(19.7748, grad_fn=<DivBackward0>)
# Epoch Number1849
# Losstensor(19.7735, grad_fn=<DivBackward0>)
# Epoch Number1850
# Losstensor(19.7722, grad_fn=<DivBackward0>)
# Epoch Number1851
# Losstensor(19.7709, grad_fn=<DivBackward0>)
# Epoch Number1852
# Losstensor(19.7696, grad_fn=<DivBackward0>)
# Epoch Number1853
# Losstensor(19.7683, grad_fn=<DivBackward0>)
# Epoch Number1854
# Losstensor(19.7670, grad_fn=<DivBackward0>)
# Epoch Number1855
# Losstensor(19.7657, grad_fn=<DivBackward0>)
# Epoch Number1856
# Losstensor(19.7644, grad_fn=<DivBackward0>)
# Epoch Number1857
# Losstensor(19.7631, grad_fn=<DivBackward0>)
# Epoch Number1858
# Losstensor(19.7618, grad_fn=<DivBackward0>)
# Epoch Number1859
# Losstensor(19.7605, grad_fn=<DivBackward0>)
# Epoch Number1860
# Losstensor(19.7593, grad_fn=<DivBackward0>)
# Epoch Number1861
# Losstensor(19.7580, grad_fn=<DivBackward0>)
# Epoch Number1862
# Losstensor(19.7567, grad_fn=<DivBackward0>)
# Epoch Number1863
# Losstensor(19.7555, grad_fn=<DivBackward0>)
# Epoch Number1864
# Losstensor(19.7542, grad_fn=<DivBackward0>)
# Epoch Number1865
# Losstensor(19.7529, grad_fn=<DivBackward0>)
# Epoch Number1866
# Losstensor(19.7517, grad_fn=<DivBackward0>)
# Epoch Number1867
# Losstensor(19.7504, grad_fn=<DivBackward0>)
# Epoch Number1868
# Losstensor(19.7492, grad_fn=<DivBackward0>)
# Epoch Number1869
# Losstensor(19.7479, grad_fn=<DivBackward0>)
# Epoch Number1870
# Losstensor(19.7467, grad_fn=<DivBackward0>)
# Epoch Number1871
# Losstensor(19.7454, grad_fn=<DivBackward0>)
# Epoch Number1872
# Losstensor(19.7442, grad_fn=<DivBackward0>)
# Epoch Number1873
# Losstensor(19.7429, grad_fn=<DivBackward0>)
# Epoch Number1874
# Losstensor(19.7417, grad_fn=<DivBackward0>)
# Epoch Number1875
# Losstensor(19.7405, grad_fn=<DivBackward0>)
# Epoch Number1876
# Losstensor(19.7392, grad_fn=<DivBackward0>)
# Epoch Number1877
# Losstensor(19.7380, grad_fn=<DivBackward0>)
# Epoch Number1878
# Losstensor(19.7368, grad_fn=<DivBackward0>)
# Epoch Number1879
# Losstensor(19.7356, grad_fn=<DivBackward0>)
# Epoch Number1880
# Losstensor(19.7344, grad_fn=<DivBackward0>)
# Epoch Number1881
# Losstensor(19.7332, grad_fn=<DivBackward0>)
# Epoch Number1882
# Losstensor(19.7319, grad_fn=<DivBackward0>)
# Epoch Number1883
# Losstensor(19.7307, grad_fn=<DivBackward0>)
# Epoch Number1884
# Losstensor(19.7295, grad_fn=<DivBackward0>)
# Epoch Number1885
# Losstensor(19.7283, grad_fn=<DivBackward0>)
# Epoch Number1886
# Losstensor(19.7271, grad_fn=<DivBackward0>)
# Epoch Number1887
# Losstensor(19.7259, grad_fn=<DivBackward0>)
# Epoch Number1888
# Losstensor(19.7247, grad_fn=<DivBackward0>)
# Epoch Number1889
# Losstensor(19.7236, grad_fn=<DivBackward0>)
# Epoch Number1890
# Losstensor(19.7224, grad_fn=<DivBackward0>)
# Epoch Number1891
# Losstensor(19.7212, grad_fn=<DivBackward0>)
# Epoch Number1892
# Losstensor(19.7200, grad_fn=<DivBackward0>)
# Epoch Number1893
# Losstensor(19.7188, grad_fn=<DivBackward0>)
# Epoch Number1894
# Losstensor(19.7177, grad_fn=<DivBackward0>)
# Epoch Number1895
# Losstensor(19.7165, grad_fn=<DivBackward0>)
# Epoch Number1896
# Losstensor(19.7153, grad_fn=<DivBackward0>)
# Epoch Number1897
# Losstensor(19.7141, grad_fn=<DivBackward0>)
# Epoch Number1898
# Losstensor(19.7130, grad_fn=<DivBackward0>)
# Epoch Number1899
# Losstensor(19.7118, grad_fn=<DivBackward0>)
# Epoch Number1900
# Losstensor(19.7106, grad_fn=<DivBackward0>)
# Epoch Number1901
# Losstensor(19.7095, grad_fn=<DivBackward0>)
# Epoch Number1902
# Losstensor(19.7084, grad_fn=<DivBackward0>)
# Epoch Number1903
# Losstensor(19.7072, grad_fn=<DivBackward0>)
# Epoch Number1904
# Losstensor(19.7061, grad_fn=<DivBackward0>)
# Epoch Number1905
# Losstensor(19.7049, grad_fn=<DivBackward0>)
# Epoch Number1906
# Losstensor(19.7038, grad_fn=<DivBackward0>)
# Epoch Number1907
# Losstensor(19.7026, grad_fn=<DivBackward0>)
# Epoch Number1908
# Losstensor(19.7015, grad_fn=<DivBackward0>)
# Epoch Number1909
# Losstensor(19.7004, grad_fn=<DivBackward0>)
# Epoch Number1910
# Losstensor(19.6992, grad_fn=<DivBackward0>)
# Epoch Number1911
# Losstensor(19.6981, grad_fn=<DivBackward0>)
# Epoch Number1912
# Losstensor(19.6970, grad_fn=<DivBackward0>)
# Epoch Number1913
# Losstensor(19.6959, grad_fn=<DivBackward0>)
# Epoch Number1914
# Losstensor(19.6947, grad_fn=<DivBackward0>)
# Epoch Number1915
# Losstensor(19.6936, grad_fn=<DivBackward0>)
# Epoch Number1916
# Losstensor(19.6925, grad_fn=<DivBackward0>)
# Epoch Number1917
# Losstensor(19.6914, grad_fn=<DivBackward0>)
# Epoch Number1918
# Losstensor(19.6903, grad_fn=<DivBackward0>)
# Epoch Number1919
# Losstensor(19.6892, grad_fn=<DivBackward0>)
# Epoch Number1920
# Losstensor(19.6881, grad_fn=<DivBackward0>)
# Epoch Number1921
# Losstensor(19.6870, grad_fn=<DivBackward0>)
# Epoch Number1922
# Losstensor(19.6859, grad_fn=<DivBackward0>)
# Epoch Number1923
# Losstensor(19.6848, grad_fn=<DivBackward0>)
# Epoch Number1924
# Losstensor(19.6837, grad_fn=<DivBackward0>)
# Epoch Number1925
# Losstensor(19.6826, grad_fn=<DivBackward0>)
# Epoch Number1926
# Losstensor(19.6816, grad_fn=<DivBackward0>)
# Epoch Number1927
# Losstensor(19.6805, grad_fn=<DivBackward0>)
# Epoch Number1928
# Losstensor(19.6794, grad_fn=<DivBackward0>)
# Epoch Number1929
# Losstensor(19.6783, grad_fn=<DivBackward0>)
# Epoch Number1930
# Losstensor(19.6772, grad_fn=<DivBackward0>)
# Epoch Number1931
# Losstensor(19.6762, grad_fn=<DivBackward0>)
# Epoch Number1932
# Losstensor(19.6751, grad_fn=<DivBackward0>)
# Epoch Number1933
# Losstensor(19.6740, grad_fn=<DivBackward0>)
# Epoch Number1934
# Losstensor(19.6730, grad_fn=<DivBackward0>)
# Epoch Number1935
# Losstensor(19.6719, grad_fn=<DivBackward0>)
# Epoch Number1936
# Losstensor(19.6708, grad_fn=<DivBackward0>)
# Epoch Number1937
# Losstensor(19.6698, grad_fn=<DivBackward0>)
# Epoch Number1938
# Losstensor(19.6687, grad_fn=<DivBackward0>)
# Epoch Number1939
# Losstensor(19.6677, grad_fn=<DivBackward0>)
# Epoch Number1940
# Losstensor(19.6666, grad_fn=<DivBackward0>)
# Epoch Number1941
# Losstensor(19.6656, grad_fn=<DivBackward0>)
# Epoch Number1942
# Losstensor(19.6646, grad_fn=<DivBackward0>)
# Epoch Number1943
# Losstensor(19.6635, grad_fn=<DivBackward0>)
# Epoch Number1944
# Losstensor(19.6625, grad_fn=<DivBackward0>)
# Epoch Number1945
# Losstensor(19.6615, grad_fn=<DivBackward0>)
# Epoch Number1946
# Losstensor(19.6604, grad_fn=<DivBackward0>)
# Epoch Number1947
# Losstensor(19.6594, grad_fn=<DivBackward0>)
# Epoch Number1948
# Losstensor(19.6583, grad_fn=<DivBackward0>)
# Epoch Number1949
# Losstensor(19.6573, grad_fn=<DivBackward0>)
# Epoch Number1950
# Losstensor(19.6563, grad_fn=<DivBackward0>)
# Epoch Number1951
# Losstensor(19.6553, grad_fn=<DivBackward0>)
# Epoch Number1952
# Losstensor(19.6542, grad_fn=<DivBackward0>)
# Epoch Number1953
# Losstensor(19.6532, grad_fn=<DivBackward0>)
# Epoch Number1954
# Losstensor(19.6522, grad_fn=<DivBackward0>)
# Epoch Number1955
# Losstensor(19.6512, grad_fn=<DivBackward0>)
# Epoch Number1956
# Losstensor(19.6502, grad_fn=<DivBackward0>)
# Epoch Number1957
# Losstensor(19.6492, grad_fn=<DivBackward0>)
# Epoch Number1958
# Losstensor(19.6482, grad_fn=<DivBackward0>)
# Epoch Number1959
# Losstensor(19.6472, grad_fn=<DivBackward0>)
# Epoch Number1960
# Losstensor(19.6462, grad_fn=<DivBackward0>)
# Epoch Number1961
# Losstensor(19.6452, grad_fn=<DivBackward0>)
# Epoch Number1962
# Losstensor(19.6442, grad_fn=<DivBackward0>)
# Epoch Number1963
# Losstensor(19.6432, grad_fn=<DivBackward0>)
# Epoch Number1964
# Losstensor(19.6422, grad_fn=<DivBackward0>)
# Epoch Number1965
# Losstensor(19.6413, grad_fn=<DivBackward0>)
# Epoch Number1966
# Losstensor(19.6403, grad_fn=<DivBackward0>)
# Epoch Number1967
# Losstensor(19.6393, grad_fn=<DivBackward0>)
# Epoch Number1968
# Losstensor(19.6383, grad_fn=<DivBackward0>)
# Epoch Number1969
# Losstensor(19.6374, grad_fn=<DivBackward0>)
# Epoch Number1970
# Losstensor(19.6364, grad_fn=<DivBackward0>)
# Epoch Number1971
# Losstensor(19.6354, grad_fn=<DivBackward0>)
# Epoch Number1972
# Losstensor(19.6344, grad_fn=<DivBackward0>)
# Epoch Number1973
# Losstensor(19.6335, grad_fn=<DivBackward0>)
# Epoch Number1974
# Losstensor(19.6325, grad_fn=<DivBackward0>)
# Epoch Number1975
# Losstensor(19.6315, grad_fn=<DivBackward0>)
# Epoch Number1976
# Losstensor(19.6306, grad_fn=<DivBackward0>)
# Epoch Number1977
# Losstensor(19.6296, grad_fn=<DivBackward0>)
# Epoch Number1978
# Losstensor(19.6287, grad_fn=<DivBackward0>)
# Epoch Number1979
# Losstensor(19.6277, grad_fn=<DivBackward0>)
# Epoch Number1980
# Losstensor(19.6268, grad_fn=<DivBackward0>)
# Epoch Number1981
# Losstensor(19.6258, grad_fn=<DivBackward0>)
# Epoch Number1982
# Losstensor(19.6249, grad_fn=<DivBackward0>)
# Epoch Number1983
# Losstensor(19.6239, grad_fn=<DivBackward0>)
# Epoch Number1984
# Losstensor(19.6230, grad_fn=<DivBackward0>)
# Epoch Number1985
# Losstensor(19.6221, grad_fn=<DivBackward0>)
# Epoch Number1986
# Losstensor(19.6211, grad_fn=<DivBackward0>)
# Epoch Number1987
# Losstensor(19.6202, grad_fn=<DivBackward0>)
# Epoch Number1988
# Losstensor(19.6193, grad_fn=<DivBackward0>)
# Epoch Number1989
# Losstensor(19.6183, grad_fn=<DivBackward0>)
# Epoch Number1990
# Losstensor(19.6174, grad_fn=<DivBackward0>)
# Epoch Number1991
# Losstensor(19.6165, grad_fn=<DivBackward0>)
# Epoch Number1992
# Losstensor(19.6156, grad_fn=<DivBackward0>)
# Epoch Number1993
# Losstensor(19.6147, grad_fn=<DivBackward0>)
# Epoch Number1994
# Losstensor(19.6137, grad_fn=<DivBackward0>)
# Epoch Number1995
# Losstensor(19.6128, grad_fn=<DivBackward0>)
# Epoch Number1996
# Losstensor(19.6119, grad_fn=<DivBackward0>)
# Epoch Number1997
# Losstensor(19.6110, grad_fn=<DivBackward0>)
# Epoch Number1998
# Losstensor(19.6101, grad_fn=<DivBackward0>)
# Epoch Number1999
# Losstensor(19.6092, grad_fn=<DivBackward0>)

# %%
print('Predictions\n', predictions)
print('Targets\n', targets_tensor)
# Out:
# Predictions
#  tensor([[ 53.3453,  66.4061],
#         [ 81.8432, 101.1297],
#         [122.7640, 129.6382],
#         [ 24.4748,  40.6305],
#         [111.6613, 123.4151]], grad_fn=<AddBackward0>)
# Targets
#  tensor([[ 58.,  77.],
#         [ 78., 100.],
#         [122., 130.],
#         [ 25.,  35.],
#         [113., 120.]])

# %%
print('MSE:',meanSquaredError(predictionTensor=predictions, targetsTensor=targets_tensor))
# Out:
# MSE: tensor(19.6092, grad_fn=<DivBackward0>)
